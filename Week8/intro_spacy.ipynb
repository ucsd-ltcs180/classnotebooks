# %%
import spacy
from spacy import displacy
from spacy.tokens import Span
import pandas as pd
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/jacobo/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# NLTK provides a very small version of the gutenberg corpus. So, I downloaded and cleaned manually a text from Gutenberg  that suited better my needs, namely "From Pole to Pole" by Sven Anders Hedin.

# %%
text = open("FromPoleToPole.txt").read()

# %% [markdown]
# Now I load the English language model and process the tex with it, what result into an annotated document that I name 'doc'.

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# %% [markdown]
# Since *From Pole to Pole* mentions a lot of places, and locattions, I want to extract all Named Entities.

# %%
for ent in doc.ents:
    print(ent, ent.label_)
# Out:
# Stockholm GPE
# all night TIME
# next morning TIME
# Sweden GPE
# Trelleborg ORG
# the Baltic Sea LOC
# Stockholm GPE
# yesterday DATE
# evening TIME
# the Baltic Sea LOC
# Berlin GPE
# Germany GPE
# quay GPE
# Swedish NORP
# the Baltic Sea LOC
# 370 feet QUANTITY
# first ORDINAL
# Swedish NORP
# German NORP
# Swedish NORP
# German NORP
# the day DATE
# Trelleborg ORG
# Baltic LOC
# Swedes NORP
# Danes NORP
# Russians NORP
# Germans NORP
# summer days DATE
# Four hours TIME
# Rügen ORG
# Germany GPE
# Sassnitz ORG
# German NORP
# a few minutes TIME
# German NORP
# Rügen ORG
# Rügen ORG
# the Baltic Sea LOC
# Sweden GPE
# Rügen PERSON
# Stralsund PERSON
# Swedish NORP
# Gustavus Adolphus PERSON
# Stralsund Charles XII. PERSON
# a year DATE
# Pomerania GPE
# Brandenburg PERSON
# autumn evening TIME
# North German NORP
# Sweden GPE
# Swedish NORP
# the winter DATE
# North German NORP
# Swedish NORP
# Scandinavian NORP
# Europe LOC
# the Ice Age EVENT
# Scandinavia LOC
# the Baltic Sea LOC
# northern Germany GPE
# Scandinavia LOC
# the night TIME
# one CARDINAL
# third ORDINAL
# Europe LOC
# Berlin GPE
# BERLIN ORG
# Europe LOC
# North Germany GPE
# Berlin GPE
# Berlin GPE
# Germany GPE
# Europe LOC
# some hundreds of miles CARDINAL
# Europe LOC
# Scandinavia LOC
# Russia GPE
# Europe LOC
# winter DATE
# summer DATE
# night TIME
# Europe LOC
# the last twenty years DATE
# Berlin GPE
# Europe LOC
# London GPE
# Paris GPE
# Continent LOC
# Berlin GPE
# Paris GPE
# St.
# Petersburg GPE
# Stockholm GPE
# Rome GPE
# Hamburg GPE
# Vienna GPE
# Berlin GPE
# Europe LOC
# Berlin GPE
# Stockholm GPE
# the Frederick Street Station FAC
# the City Railway GPE
# the "King's PRODUCT
# Germans NORP
# French NORP
# 1871 DATE
# three CARDINAL
# France GPE
# Tiergarten WORK_OF_ART
# Berlin GPE
# Sundays DATE
# the Brandenburg Gate FAC
# Doric PERSON
# four CARDINAL
# German NORP
# Berlin GPE
# France GPE
# German NORP
# Europe LOC
# Berlin GPE
# Germany GPE
# Unter den Linden WORK_OF_ART
# Berlin GPE
# only two-thirds CARDINAL
# 66 yards QUANTITY
# four CARDINAL
# grey square FAC
# Unter den Linden WORK_OF_ART
# German NORP
# Kaiser Wilhelm PERSON
# just noon TIME
# Imperial Guard ORG
# Royal Library ORG
# Frederick the Great PERSON
# the Opera House ORG
# University ORG
# ten thousand CARDINAL
# Arsenal LOC
# the "Schlossbrücke PRODUCT
# Palace Bridge FAC
# Frederick William III PERSON
# Berlin GPE
# daily DATE
# Lustgarten FAC
# Cathedral ORG
# the Royal Palace ORG
# Plate I. PERSON
# the Imperial Court ORG
# Germany GPE
# nine CARDINAL
# Palace LOC
# Beef WORK_OF_ART
# Prussia GPE
# the Royal Palace ORG
# Cathedral ORG
# Lustgarten FAC
# the River Spree WORK_OF_ART
# China GPE
# Japan GPE
# Imperial ORG
# Empress PRODUCT
# William II PERSON
# Swedish NORP
# Asia LOC
# Alexander ORG
# Asia LOC
# two thousand years DATE
# Chinese NORP
# Tibet GPE
# German NORP
# four CARDINAL
# Prussia GPE
# Bavaria GPE
# Saxony GPE
# Würtemberg ORG
# six CARDINAL
# Alsace-Lorraine ORG
# three CARDINAL
# Hamburg GPE
# Lübeck GPE
# Bremen PERSON
# 207 CARDINAL
# more than 25,000 CARDINAL
# seven CARDINAL
# more than half a million CARDINAL
# Berlin GPE
# Hamburg GPE
# Munich GPE
# Dresden GPE
# Leipzig GPE
# Breslau PERSON
# Cologne GPE
# England GPE
# Scotland GPE
# BERLIN ORG
# Berlin GPE
# Vienna GPE
# Austria GPE
# Brandenburg GPE
# Elbe ORG
# the North Sea LOC
# Hamburg GPE
# Oder ORG
# the Baltic Sea LOC
# Elbe ORG
# Dresden PERSON
# Saxony GPE
# Austrian NORP
# Bohemia GPE
# Prague GPE
# a few days DATE
# one CARDINAL
# Europe LOC
# Vienna GPE
# Francis Joseph PERSON
# Vienna GPE
# fourth ORDINAL
# Europe LOC
# Berlin GPE
# the present day DATE
# Ring WORK_OF_ART
# St.
# Stephen's Church GPE
# two million CARDINAL
# Vienna GPE
# Berlin GPE
# Danube PERSON
# twelve CARDINAL
# Vienna GPE
# Danube PERSON
# Viennese NORP
# Vienna GPE
# one CARDINAL
# august DATE
# Fifty millions CARDINAL
# Germans NORP
# Austria GPE
# Chechs GPE
# Bohemia GPE
# Magyars GPE
# Hungary GPE
# Polacks GPE
# Galicia GPE
# Mohammedans NORP
# Catholic NORP
# the present day DATE
# eighty-two years old DATE
# sixty-four years DATE
# 1867 DATE
# Hungary GPE
# Danube PERSON
# Austria GPE
# Hungary GPE
# Danube PERSON
# Dniester ORG
# the Adriatic Sea LOC
# Danube ORG
# Volga ORG
# Europe LOC
# Caspian NORP
# Danube PERSON
# the Black Sea LOC
# the Black Forest ORG
# Baden GPE
# 1800 miles QUANTITY
# Danube PERSON
# Bavaria GPE
# Austria GPE
# Hungary GPE
# Rumania GPE
# Bulgaria GPE
# Russian NORP
# sixty CARDINAL
# more than half CARDINAL
# Europe LOC
# Budapest GPE
# two CARDINAL
# five CARDINAL
# The Elizabeth Bridge ORG
# 950 feet QUANTITY
# Wallachia ORG
# nearly two-thirds CARDINAL
# a mile QUANTITY
# Rumanian NORP
# Danube PERSON
# Chernovodsk PERSON
# Danube PERSON
# three CARDINAL
# millions CARDINAL
# Central Europe LOC
# Danube PERSON
# Europe LOC
# South Germany GPE
# Bohemia GPE
# Carpathians ORG
# Alps GPE
# the Balkan Peninsula LOC
# Budapest GPE
# Hungarian NORP
# winter DATE
# the summer DATE
# Hungarian NORP
# Magyar GPE
# poplars ORG
# Hungary GPE
# bee ORG
# one CARDINAL
# Hungary GPE
# Tatar ORG
# Arabian NORP
# a few hours TIME
# Budapest GPE
# Hungarian NORP
# autumn DATE
# Hungarian NORP
# Danube PERSON
# Belgrade GPE
# Servia GPE
# Danube PERSON
# Morava PRODUCT
# Servian NORP
# green heights GPE
# Morava PRODUCT
# Morava PRODUCT
# Danube ORG
# Servia GPE
# Sofia GPE
# Bulgaria GPE
# Danube ORG
# States GPE
# Innumerable PRODUCT
# Danube PERSON
# Europe LOC
# Danube PERSON
# the present day DATE
# Continent LOC
# Bulgaria GPE
# Maritza ORG
# Turkish NORP
# the Balkan Peninsula LOC
# Balkan NORP
# Albania GPE
# Macedonia GPE
# Alexander the Great ORG
# Greece GPE
# Turkey GPE
# Constantinople GPE
# Stambul GPE
# Stambul GPE
# the Turkish quarter DATE
# mosques FAC
# Plate II ORG
# St.
# Sophia GPE
# Rome GPE
# seven CARDINAL
# Stambul GPE
# two quarters DATE
# Galata ORG
# Pera ORG
# Europeans NORP
# Greeks PERSON
# Italians NORP
# Jews NORP
# Armenians NORP
# the Balkan Peninsula LOC
# Asia Minor GPE
# Caucasia GPE
# Stambul GPE
# the Golden Horn FAC
# the Black Sea LOC
# Bosporus PERSON
# Scutari PERSON
# Scutari ORG
# third ORDINAL
# three CARDINAL
# Europe LOC
# Scutari PERSON
# Asia LOC
# the Sea of Marmora LOC
# Dardanelles ORG
# Hellespont GPE
# The Sea of Marmora LOC
# 130 miles QUANTITY
# Seven miles QUANTITY
# Princes ORG
# Asia Minor GPE
# two CARDINAL
# two CARDINAL
# Europe LOC
# Asia LOC
# Turks NORP
# Asia LOC
# Europe LOC
# daily DATE
# Bosporus PERSON
# Bulgaria GPE
# Rumania GPE
# Russia GPE
# Asia Minor ORG
# Dardanelles GPE
# Greece GPE
# Archipelago LOC
# Mediterranean LOC
# Bosporus PERSON
# Asiatic GPE
# Turks NORP
# THE CHURCH OF THE DIVINE WISDOM
# Let us ORG
# 450 years DATE
# the Christian Cross ORG
# the year DATE
# 548 CARDINAL
# D. NORP
# One CARDINAL
# Christendom ORG
# first ORDINAL
# Asia Minor LOC
# sixteen years DATE
# ten thousand CARDINAL
# the Church of the Divine Wisdom ORG
# Hagia Sophia PERSON
# Byzantine NORP
# Justinian NORP
# four CARDINAL
# the Patriarch of Constantinople ORG
# 180 feet QUANTITY
# Justinian NORP
# mosaic PRODUCT
# hundred CARDINAL
# seven CARDINAL
# a hundred pounds QUANTITY
# the Church of the Divine Wisdom ORG
# forty thousand CARDINAL
# twenty-four CARDINAL
# two hundred pounds QUANTITY
# Redeemer ORG
# the Mother of God ORG
# twelve CARDINAL
# the Holy of Holies ORG
# more than five hundred years ago CARDINAL
# Roman NORP
# Jerusalem GPE
# Justinian NORP
# three CARDINAL
# Noah ORG
# four CARDINAL
# two CARDINAL
# first ORDINAL
# Ezekiel PERSON
# Exodus PRODUCT
# xxxvii GPE
# Justinian NORP
# Solomon PERSON
# fourteen days DATE
# Christians NORP
# Church ORG
# Church Councils ORG
# the year DATE
# Nearly a thousand years DATE
# May 29, 1453 DATE
# May DATE
# a fine month DATE
# Constantinople GPE
# The summer DATE
# Bosporus PERSON
# this day DATE
# May, 1453 DATE
# the early morning TIME
# Turkish NORP
# St.
# Sophia GPE
# A hundred thousand CARDINAL
# Abashed PERSON
# Christians NORP
# Mohammedan PERSON
# Mohammedans NORP
# Prophet PERSON
# Turks NORP
# Redeemer ORG
# Mohammedan ORG
# Christians NORP
# Greek NORP
# Christians NORP
# Turks NORP
# Four centuries and a half DATE
# Greeks PERSON
# the day DATE
# St.
# Sophia GPE
# Christian NORP
# Turks NORP
# midday TIME
# Mohammedan ORG
# Mohammed II PERSON
# Conqueror ORG
# Turks NORP
# a thousand years ago DATE
# the Emperor Justinian ORG
# first ORDINAL
# Sultan LOC
# Sultan NORP
# Christian NORP
# the Church of the Holy Wisdom ORG
# Islam ORG
# Four and a half centuries DATE
# the day DATE
# the Church of the Holy Wisdom ORG
# Turks NORP
# four CARDINAL
# four CARDINAL
# Mohammed PERSON
# the month DATE
# Mohammedans NORP
# each day DATE
# Prophet PERSON
# Koran WORK_OF_ART
# Church of the Divine Wisdom ORG
# Greek NORP
# thousands CARDINAL
# fifty feet QUANTITY
# Mohammed PERSON
# thirty feet QUANTITY
# Turks NORP
# Mecca GPE
# Paradise LOC
# Koran WORK_OF_ART
# Mohammedan ORG
# Persia GPE
# Turkestan GPE
# Mohammedan PERSON
# the Old World EVENT
# Arabia GPE
# Islam ORG
# Asia LOC
# Europe LOC
# Africa LOC
# Mohammedan ORG
# Africa LOC
# Mohammed PERSON
# Paradise LOC
# Paradise ORG
# STAMBUL PERSON
# Fatima Hanum PERSON
# Stambul GPE
# Emin Effendi PERSON
# one CARDINAL
# Scutari ORG
# two CARDINAL
# Fatima PERSON
# three CARDINAL
# four CARDINAL
# Fatima PERSON
# first ORDINAL
# three CARDINAL
# hours TIME
# one CARDINAL
# Fatima PERSON
# Fatima PERSON
# Hindu NORP
# bazaar ORG
# Indian NORP
# Fatima PERSON
# One CARDINAL
# the harem garden ORG
# Fatima PERSON
# Stambul GPE
# Fatima PERSON
# Emin Effendi PERSON
# Stambul GPE
# late years DATE
# Fatima PERSON
# Europeans NORP
# quay GPE
# one CARDINAL
# Two CARDINAL
# Bosporus PERSON
# Scutari PERSON
# Stambul GPE
# Fatima PERSON
# the Sea of Marmora LOC
# an hour TIME
# Fatima PERSON
# the Sea of Marmora LOC
# quay GPE
# Stambul GPE
# two CARDINAL
# summer DATE
# Stambul GPE
# Persia GPE
# India GPE
# Kashmir LOC
# Asia LOC
# Africa LOC
# Fatima PERSON
# Nishapur GPE
# Badakshan GPE
# Bahrein GPE
# the Indian Ocean LOC
# bazaar ORG
# bazaar ORG
# the Turkish Empire GPE
# Mohammedan PERSON
# half CARDINAL
# Mohammedan PERSON
# North Africa GPE
# Arabia GPE
# Asia Minor GPE
# Persia GPE
# Caucasia GPE
# Afghanistan GPE
# India GPE
# Turkestan GPE
# Stambul GPE
# one CARDINAL
# Turkish NORP
# quay GPE
# Turks NORP
# Persians NORP
# Hindus NORP
# India GPE
# Egyptians NORP
# Cairo GPE
# Arabs NORP
# the Red Sea LOC
# Circassians NORP
# Tatars GPE
# Caucasus NORP
# Crimea GPE
# Samarkand GPE
# Bokhara GPE
# Armenians NORP
# Jews NORP
# Greeks PERSON
# Zanzibar NORP
# East LOC
# East LOC
# Kurdish NORP
# Oriental NORP
# Stambul GPE
# bazaar ORG
# II CARDINAL
# CONSTANTINOPLE ORG
# 1905 DATE
# BLACK SEA LOC
# Swedish NORP
# Ali PERSON
# quay GPE
# October DATE
# morning TIME
# four CARDINAL
# Bosporus PERSON
# Russian NORP
# Bosporus PERSON
# Turkish NORP
# Paradise LOC
# Turks NORP
# Bosporus PERSON
# the night TIME
# first ORDINAL
# twenty miles QUANTITY
# less than a third CARDINAL
# two-thirds CARDINAL
# White ORG
# several feet QUANTITY
# hour after hour TIME
# European NORP
# Asiatic LOC
# Europeans NORP
# Asiatic GPE
# Terapia GPE
# summer DATE
# Christians NORP
# Turkish NORP
# seven CARDINAL
# seven CARDINAL
# Godfrey de Bouillon ORG
# the winter of 1096-1097 DATE
# Jerusalem GPE
# two CARDINAL
# the Black Sea LOC
# half an hour later TIME
# Bosporus PERSON
# Sebastopol ORG
# Crimea ORG
# the Russian Black Sea LOC
# Russians NORP
# Turks NORP
# Mediterranean LOC
# Russian NORP
# The Black Sea LOC
# Europe LOC
# four CARDINAL
# Baltic LOC
# Mediterranean LOC
# Baltic NORP
# European NORP
# Europe LOC
# Asia LOC
# Mediterranean LOC
# three CARDINAL
# Europe LOC
# Asia LOC
# Africa LOC
# Baltic NORP
# Caspian Seas PERSON
# about three CARDINAL
# England GPE
# Wales GPE
# Baltic NORP
# Atlantic LOC
# Danish NORP
# Scania GPE
# The Black Sea LOC
# only one CARDINAL
# Bosporus PERSON
# The Caspian Sea LOC
# Baltic LOC
# Landsort PERSON
# 250 CARDINAL
# Next ORG
# the Caspian Sea LOC
# 600 CARDINAL
# 85 feet QUANTITY
# the Black Sea LOC
# three CARDINAL
# 1230 CARDINAL
# three CARDINAL
# Baltic NORP
# Caspian NORP
# Four CARDINAL
# the Black Sea LOC
# Danube ORG
# Dniester PERSON
# Don PERSON
# Bosporus PERSON
# the Black Sea LOC
# Mediterranean LOC
# The Black Sea LOC
# White Sea LOC
# Yellow Sea LOC
# the Red Sea LOC
# Mediterranean LOC
# the Red Sea LOC
# the Black Sea LOC
# Sebastopol ORG
# Caucasian NORP
# Batum GPE
# Asia Minor LOC
# Proud PRODUCT
# Trebizond GPE
# midday TIME
# Turkish NORP
# TREBIZOND ORG
# Trebizond GPE
# Greek NORP
# seven hundred years DATE
# Persian NORP
# the Black Sea LOC
# Tabriz GPE
# Teheran GPE
# 800 miles QUANTITY
# the Suez Canal LOC
# Caucasian NORP
# Tabriz GPE
# Teheran GPE
# autumn DATE
# Turkish Armenia GPE
# 160 miles QUANTITY
# Turkish NORP
# Persian NORP
# November, 1905 DATE
# The Governors of Trebizond ORG
# Erzerum GPE
# six CARDINAL
# Turkish NORP
# three CARDINAL
# Caucasian NORP
# two CARDINAL
# two CARDINAL
# three CARDINAL
# Trebizond GPE
# Teheran GPE
# day DATE
# Asia LOC
# the Black Sea LOC
# Armenian NORP
# 26 CARDINAL
# 34 CARDINAL
# BAGHDAD GPE
# 37-45 DATE
# the first days DATE
# hundreds of feet QUANTITY
# Turks NORP
# day DATE
# the early morning TIME
# the nights DATE
# Turkish NORP
# Armenians NORP
# the night TIME
# Erzerum PERSON
# Christian NORP
# Armenians NORP
# Turks NORP
# three CARDINAL
# the Black Sea LOC
# the Caspian Sea LOC
# the Persian Gulf LOC
# Caucasia GPE
# Asia Minor GPE
# Mesopotamia GPE
# Euphrates LOC
# autumn DATE
# the night TIME
# Shakir NORP
# Persia GPE
# more than three hundred CARDINAL
# many thousands of years DATE
# Euphrates LOC
# Tigris GPE
# Babylon and Nineveh ORG
# the days DATE
# Alexander PERSON
# Macedonian NORP
# Euphrates LOC
# Tigris GPE
# Venetian NORP
# Marco Polo PERSON
# 620 years ago DATE
# Tabriz GPE
# Trebizond GPE
# Timur the Lame ORG
# Turks NORP
# the Sultan Bayazid ORG
# Asia LOC
# Armenian NORP
# Mount Ararat LOC
# a thousand feet QUANTITY
# Mont Blanc PERSON
# Kurdish NORP
# Persian NORP
# Persia GPE
# Azerbeijan GPE
# Tatars GPE
# Tabriz GPE
# Persia GPE
# Europe LOC
# fourteen days DATE
# Trebizond GPE
# fifth ORDINAL
# Tatar ORG
# seventh ORDINAL
# Tatars GPE
# Turks NORP
# Armenians NORP
# Tabriz GPE
# Trebizond GPE
# Ararat ORG
# Russia GPE
# Turkey GPE
# Persia GPE
# December 13 DATE
# Teheran GPE
# 800 miles QUANTITY
# a month DATE
# India GPE
# 1500 miles QUANTITY
# fourteen CARDINAL
# six CARDINAL
# Persians NORP
# Tatar ORG
# CAUCASUS ORG
# MESOPOTAMIA ORG
# 1885-6 DATE
# August 15, 1885 DATE
# St.
# Petersburg GPE
# Moscow GPE
# Rostov PERSON
# Don PERSON
# Caucasus ORG
# four days DATE
# Russia GPE
# four CARDINAL
# Russia GPE
# Caucasus PRODUCT
# next day DATE
# more than 16,000 feet QUANTITY
# Mount Kazbek NORP
# Vladikavkas ORG
# 130 miles QUANTITY
# Caucasian NORP
# spring DATE
# twenty-eight hours TIME
# Tiflis GPE
# Caucasia GPE
# the Kura River LOC
# fifteen CARDINAL
# Caucasia GPE
# Tiflis NORP
# Tiflis NORP
# Baku GPE
# Twice ORG
# the Caspian Sea LOC
# seven o'clock TIME
# Baku GPE
# ten miles QUANTITY
# seven months DATE
# yesterday DATE
# Russian NORP
# Persian NORP
# Tatar ORG
# Persia GPE
# Persia GPE
# Baku GPE
# earth LOC
# 65 feet QUANTITY
# first ORDINAL
# about 40 inches QUANTITY
# first ORDINAL
# Plate III PERSON
# as much as MONEY
# a dozen miles QUANTITY
# Black Town WORK_OF_ART
# Baku GPE
# 170 CARDINAL
# Baku GPE
# 1910 DATE
# 4094 DATE
# 2600 DATE
# Last year DATE
# about eight million tons QUANTITY
# nearly 300 tons QUANTITY
# twenty-four hours TIME
# 2000 DATE
# about 20 CARDINAL
# 2800 feet QUANTITY
# Late one evening TIME
# February, 1886 DATE
# One CARDINAL
# Tatar ORG
# Baku GPE
# April 6, 1886 DATE
# Tatar ORG
# Baki Khanoff PERSON
# about £30 MONEY
# two CARDINAL
# Tatar ORG
# two CARDINAL
# Persia GPE
# Baki Khanoff PERSON
# 2000 miles QUANTITY
# Persia GPE
# two days DATE
# the Caspian Sea LOC
# Persian NORP
# Persians NORP
# two CARDINAL
# the Elburz Mountains LOC
# Karzan GPE
# next day DATE
# all night TIME
# first ORDINAL
# one CARDINAL
# Baki Khanoff PERSON
# four CARDINAL
# Tatars GPE
# two CARDINAL
# Persians NORP
# seven CARDINAL
# the night TIME
# twenty-one years of age one DATE
# Teheran GPE
# Persia GPE
# Baki Khanoff PERSON
# Baku GPE
# Teheran GPE
# about £30 MONEY
# April 27 DATE
# Kashan GPE
# Kuhrud GPE
# some hours TIME
# four hours TIME
# the night TIME
# Kuhrud GPE
# nomad ORG
# Kuhrud GPE
# one CARDINAL
# the middle of the night DATE
# European NORP
# two hours later TIME
# fifteen hours TIME
# A few days DATE
# Persia GPE
# Ispahan GPE
# mosques FAC
# Persian NORP
# Persepolis GPE
# Persian NORP
# Xerxes ORG
# Darius ORG
# the 2400 years DATE
# Persepolis GPE
# Persia GPE
# Shiraz PERSON
# Persia GPE
# the Persian Gulf LOC
# one day DATE
# 102 CARDINAL
# the night TIME
# all night TIME
# the Persian Gulf LOC
# May 22 DATE
# Bushire GPE
# eastern coast LOC
# The Persian Gulf LOC
# the Indian Ocean LOC
# Persia GPE
# Arabia GPE
# Bahrein GPE
# Arabian NORP
# British NORP
# summer DATE
# about £900,000 MONEY
# As many as a thousand CARDINAL
# thirty thousand CARDINAL
# Indian NORP
# seven CARDINAL
# most fifty seconds TIME
# the Persian Gulf LOC
# the Red Sea LOC
# Mediterranean LOC
# the Indian Ocean LOC
# Arabia ORG
# Europe LOC
# Sultan LOC
# Turkey GPE
# Beduins PERSON
# European NORP
# the Red Sea LOC
# two CARDINAL
# Arab NORP
# Mohammedans NORP
# Jerusalem GPE
# Rome GPE
# Christians NORP
# Mecca GPE
# Mohammed PERSON
# the year A.
# D. DATE
# 570 CARDINAL
# Medina GPE
# 632 CARDINAL
# Mohammedan PERSON
# Islamism NORP
# Arabs NORP
# the Old World EVENT
# 217 millions CARDINAL
# Islam ORG
# Mecca GPE
# Hajji GPE
# Africa LOC
# Asia LOC
# annually DATE
# Adjoining Arabia GPE
# Mesopotamia GPE
# Euphrates LOC
# Tigris GPE
# English NORP
# Bushire GPE
# Tigris ORG
# half CARDINAL
# Arabs NORP
# a few days DATE
# Baghdad GPE
# the eleventh century DATE
# Baghdad GPE
# Mohammedans NORP
# Indian NORP
# Arabic NORP
# Baghdad GPE
# Euphrates ORG
# a hundred CARDINAL
# Jewish NORP
# harps NORP
# Baghdad GPE
# 5 MONEY
# Persian NORP
# kran GPE
# kran GPE
# about seven-pence CARDINAL
# Teheran GPE
# 600 miles QUANTITY
# Kermanshah GPE
# 200 miles QUANTITY
# Kermanshah PERSON
# English NORP
# fifty CARDINAL
# ten CARDINAL
# Arab NORP
# Eight CARDINAL
# Chaldean ORG
# fifty CARDINAL
# ten o'clock TIME
# June 6 DATE
# Two CARDINAL
# Arabs NORP
# Baghdad GPE
# summer night TIME
# thousands CARDINAL
# Arabs NORP
# the month DATE
# two CARDINAL
# Arabs NORP
# two o'clock in the morning TIME
# Two o'clock TIME
# Arab NORP
# half CARDINAL
# Baghdad GPE
# hyænas GPE
# seven hours TIME
# Arabs NORP
# all day DATE
# Next night TIME
# eight hours TIME
# Bakuba GPE
# Plate IV PERSON
# three CARDINAL
# Turkish NORP
# ten CARDINAL
# two CARDINAL
# Arabs NORP
# six CARDINAL
# Arabs NORP
# nine o'clock TIME
# all night TIME
# the day DATE
# Arab NORP
# Baghdad GPE
# Arab NORP
# twenty-five CARDINAL
# first ORDINAL
# Kermanshah GPE
# June 13 DATE
# Arab NORP
# Mohammedans NORP
# Arab NORP
# Agha Hassan PERSON
# Agha Hassan PERSON
# Baghdad GPE
# Swede NORP
# Swede WORK_OF_ART
# Sweden GPE
# Russia GPE
# Ironhead ORG
# Charles XII PERSON
# Charles the Twelfth's PERSON
# Sweden GPE
# first ORDINAL
# six months DATE
# more than three days DATE
# three weeks DATE
# Teheran GPE
# Persian NORP
# Two CARDINAL
# Arab NORP
# the whole day DATE
# night TIME
# Nights TIME
# the last day DATE
# one CARDINAL
# Agha Hassan PERSON
# midnight TIME
# all night TIME
# the fasting month DATE
# three CARDINAL
# 105 miles QUANTITY
# sixteen hours TIME
# three CARDINAL
# hour TIME
# Hamadan GPE
# nine CARDINAL
# Teheran GPE
# half CARDINAL
# IV PERSON
# THE PERSIAN DESERT (1906 ORG
# India GPE
# 33 CARDINAL
# Teheran GPE
# Trebizond GPE
# six CARDINAL
# Persians NORP
# one CARDINAL
# Tatar ORG
# fourteen CARDINAL
# January 1 DATE
# two CARDINAL
# first ORDINAL
# one CARDINAL
# Two CARDINAL
# Teheran GPE
# Plate V. PERSON
# Camels ORG
# two CARDINAL
# two CARDINAL
# first ORDINAL
# ten hours TIME
# several months DATE
# the morning TIME
# more than twenty miles QUANTITY
# a day DATE
# the Elburz Mountains LOC
# Teheran GPE
# two days DATE
# ten CARDINAL
# a few days DATE
# Kevir PERSON
# winter DATE
# Kevir PERSON
# Hitherto PERSON
# one day DATE
# winter DATE
# 25 degrees QUANTITY
# the night TIME
# several days DATE
# four or five days DATE
# several feet QUANTITY
# Jandak ORG
# only two CARDINAL
# four CARDINAL
# four days DATE
# Kevir PERSON
# Persians NORP
# the day DATE
# the night TIME
# Persians NORP
# Gulam Hussein PERSON
# Another night TIME
# This night TIME
# the night TIME
# midnight TIME
# Persians NORP
# first ORDINAL
# a minute TIME
# second ORDINAL
# the eleventh hour EVENT
# four CARDINAL
# one CARDINAL
# One CARDINAL
# Devil PERSON
# first ORDINAL
# Two more hours TIME
# Gulam Hussein PERSON
# weeks DATE
# two months DATE
# Persians NORP
# Tebbes GPE
# 73 CARDINAL
# Plate VI ORG
# Persian NORP
# Tebbes PERSON
# the fall of day DATE
# evening TIME
# Persian NORP
# night TIME
# One night TIME
# two CARDINAL
# Tebbes PERSON
# every night TIME
# Cape Verde LOC
# the Old World EVENT
# India GPE
# Simla PERSON
# 1882 DATE
# 359 CARDINAL
# Bengal GPE
# hydrophobia GPE
# the last Boundary Commission ORG
# Seistan GPE
# one night TIME
# six weeks DATE
# winter DATE
# Englishmen PERSON
# three CARDINAL
# more than a hundred CARDINAL
# day DATE
# seventy-eight CARDINAL
# Twenty years ago DATE
# Caspian NORP
# Persia GPE
# one evening TIME
# the Elburz Mountains LOC
# five feet QUANTITY
# two CARDINAL
# Two hours later TIME
# half a dozen CARDINAL
# that night TIME
# a minute TIME
# one CARDINAL
# the day DATE
# two or three CARDINAL
# night TIME
# Persia GPE
# four CARDINAL
# Tebbes PERSON
# Tebbes ORG
# Meshed ORG
# only a few days' DATE
# Persia GPE
# Russian Asia LOC
# Transcaspia ORG
# Samarcand ORG
# Bukhara GPE
# Turkestan GPE
# the Kirghiz Steppe FAC
# India GPE
# Tebbes PERSON
# THE KIRGHIZ STEPPE ORG
# 1893-5 DATE
# the Kirghiz Steppe FAC
# November, 1893 DATE
# Orenburg GPE
# the Ural River LOC
# Asia LOC
# Europe LOC
# Russian NORP
# two CARDINAL
# ninety-nine CARDINAL
# Orenburg GPE
# Tashkent GPE
# Russian NORP
# nineteen days DATE
# first ORDINAL
# three CARDINAL
# Orenburg GPE
# Asia LOC
# two CARDINAL
# three hours TIME
# Russian NORP
# first ORDINAL
# two CARDINAL
# Orsk PRODUCT
# twenty years DATE
# two CARDINAL
# six thousand miles QUANTITY
# forty-eight hours TIME
# Orsk DATE
# the Ural River LOC
# Asiatic LOC
# Kirghiz Steppe PERSON
# the Caspian Sea LOC
# the Ural River LOC
# Day after day DATE
# foot CARDINAL
# Kirghizes ORG
# one CARDINAL
# two CARDINAL
# Kirghiz ORG
# Kirghiz ORG
# two CARDINAL
# Kirghiz GPE
# one CARDINAL
# three CARDINAL
# the Sea of Aral LOC
# two CARDINAL
# Oxus PERSON
# Pamir ORG
# the Sea of Aral LOC
# Scotland GPE
# geese NORP
# one CARDINAL
# two CARDINAL
# about two hours TIME
# two CARDINAL
# SAMARCAND ORG
# BUKHARA
# Russian Central Asia ORG
# ten million CARDINAL
# twelve CARDINAL
# the British Isles FAC
# Turkestan FAC
# Eastern Turkestan LOC
# the Caspian Sea LOC
# the Kirghiz Steppe FAC
# Afghanistan GPE
# Persia GPE
# the "Black Sand WORK_OF_ART
# two CARDINAL
# Two CARDINAL
# Turkestan PRODUCT
# the Kirghiz Steppe FAC
# Tashkent GPE
# the Caspian Sea LOC
# Tashkent GPE
# Ferghana GPE
# Ferghana ORG
# Turkestan GPE
# Tashkent GPE
# Turkestan GPE
# 200,000 CARDINAL
# Tashkent GPE
# Samarcand ORG
# Samarcand ORG
# Bukhara GPE
# Emir PERSON
# Russia GPE
# the Caspian Sea LOC
# Transcaspia ORG
# Central Asia LOC
# Russia GPE
# forty-five years ago DATE
# Transcaspia ORG
# thirty years ago DATE
# Transcaspia PERSON
# Turkomans NORP
# Persia GPE
# Bukhara GPE
# Samarcand ORG
# General Skobeleff ORG
# 1880 DATE
# one CARDINAL
# Turkomans NORP
# Russians NORP
# The Green Hill WORK_OF_ART
# about 45,000 CARDINAL
# Russian NORP
# Skobeleff PERSON
# Turkomans NORP
# Persian NORP
# some thousands CARDINAL
# Twenty thousand CARDINAL
# Turkomans NORP
# that day DATE
# Turkomans NORP
# The Green Hill WORK_OF_ART
# Russia GPE
# Turkestan FAC
# weeks DATE
# Bukhara GPE
# mosques FAC
# mulberry PERSON
# Sixty years ago DATE
# Bukhara GPE
# Emir PERSON
# mechanician NORP
# Italy GPE
# Italian NORP
# Emir PERSON
# Emir PERSON
# Italian NORP
# Islamism NORP
# Bukhara GPE
# Seventy years ago DATE
# Englishmen PRODUCT
# Asia LOC
# Jerusalem GPE
# Mecca GPE
# Benares GPE
# Lhasa GPE
# Samarcand ORG
# Mohammedans NORP
# Asia LOC
# Alexander the Great PERSON
# Central Asia LOC
# Arabs NORP
# Mongols PERSON
# Tsar GPE
# Samarcand ORG
# Timur ORG
# the year 1405 DATE
# Central Asia LOC
# Persia GPE
# Mesopotamia GPE
# South Russia GPE
# Turkey GPE
# India GPE
# This Timur the Lame ORG
# Samarcand ORG
# Timur ORG
# Bibi PERSON
# Timur PERSON
# Queen PERSON
# One night TIME
# Queen PERSON
# Samarcand ORG
# Asia LOC
# four CARDINAL
# Timur PERSON
# Islam ORG
# Koran WORK_OF_ART
# Samarcand ORG
# Turkish NORP
# Persian NORP
# autumn DATE
# winter DATE
# Samarcand ORG
# Jaipur GPE
# India GPE
# PAMIR ORG
# Samarcand ORG
# Pamir ORG
# Roof of the World WORK_OF_ART
# earth LOC
# Himalayas ORG
# Trans ORG
# Karakorum ORG
# Kuen-lun ORG
# Hindu NORP
# Asia LOC
# Europe LOC
# Tibetan NORP
# China GPE
# Indian NORP
# first ORDINAL
# Asia LOC
# Hindu NORP
# Persia GPE
# Caucasus ORG
# Asia Minor ORG
# the Balkan Peninsula LOC
# Alps GPE
# Pyrenees GPE
# Pamir ORG
# Pamir ORG
# Asia LOC
# brooks ORG
# Asiatic GPE
# the month of February, 1894 DATE
# Ferghana GPE
# Central Asia LOC
# eleven CARDINAL
# three CARDINAL
# one CARDINAL
# Islam Bay ORG
# many years DATE
# Kirghizes ORG
# two CARDINAL
# the night TIME
# one CARDINAL
# Pamir ORG
# night TIME
# Kirghizes PERSON
# One CARDINAL
# first ORDINAL
# two CARDINAL
# one CARDINAL
# Kirghiz PRODUCT
# Darkness PRODUCT
# more than twelve hours TIME
# Kirghiz ORG
# one CARDINAL
# Alai PERSON
# winter DATE
# Alai PERSON
# Two CARDINAL
# One day DATE
# four CARDINAL
# ten feet QUANTITY
# first ORDINAL
# Kirghizes ORG
# one CARDINAL
# One day DATE
# Kirghiz GPE
# 29 CARDINAL
# Kirghizes ORG
# forty CARDINAL
# Six CARDINAL
# two CARDINAL
# four CARDINAL
# Kirghizes ORG
# Kirghizes ORG
# 180 CARDINAL
# Kirghiz GPE
# Kirghiz PERSON
# a couple of days later DATE
# Kirghiz PERSON
# Two CARDINAL
# twelve CARDINAL
# winter DATE
# two CARDINAL
# Kirghiz PERSON
# one foot QUANTITY
# Two CARDINAL
# wolf PERSON
# two CARDINAL
# Kirghizes ORG
# Kirghiz GPE
# winter DATE
# Alai PERSON
# Pamir LOC
# Ovis Poli PERSON
# Marco Polo PERSON
# Tibet GPE
# Marco Polo's PERSON
# Asia LOC
# 300 miles QUANTITY
# Russian NORP
# the Eastern Pamir LOC
# the Emperor of China ORG
# the Eastern Pamir LOC
# 56 CARDINAL
# 25,800 feet QUANTITY
# crest ORG
# only a few yards QUANTITY
# the year DATE
# thither DATE
# several miles QUANTITY
# half a mile QUANTITY
# forty-five feet QUANTITY
# warm days DATE
# winter DATE
# Kirghizes ORG
# four CARDINAL
# one CARDINAL
# Kirghizes ORG
# four CARDINAL
# Islam Bay ORG
# six CARDINAL
# Kirghizes ORG
# ten CARDINAL
# first ORDINAL
# Kirghizes ORG
# the whole day DATE
# a point 20,700 feet QUANTITY
# the night TIME
# the morning TIME
# two CARDINAL
# Kirghizes ORG
# ten CARDINAL
# Kirghizes PERSON
# Light PRODUCT
# the morning TIME
# two CARDINAL
# Kirghizes ORG
# the summer of 1904 DATE
# months DATE
# Kirghiz PERSON
# half CARDINAL
# Kirghizes DATE
# the night TIME
# Mohammedans NORP
# Arabic NORP
# Kirghizes ORG
# Islam Bay PERSON
# Kirghizes ORG
# One day DATE
# Kirghizes ORG
# gymkhana PERSON
# early in the morning TIME
# forty-two QUANTITY
# Kirghizes ORG
# Kirghizes ORG
# Khoat Bek PERSON
# a hundred and CARDINAL
# years DATE
# five CARDINAL
# one CARDINAL
# Kirghiz ORG
# eighty CARDINAL
# first ORDINAL
# half CARDINAL
# one CARDINAL
# two CARDINAL
# Khoat Bek ORG
# nearly a hundred years ago DATE
# VI
# FROM PERSIA TO INDIA ORG
# 1906 DATE
# Tebbes PERSON
# India GPE
# days DATE
# weeks DATE
# Hamun ORG
# Persia GPE
# Afghanistan GPE
# Bukhara GPE
# Afghanistan GPE
# Hindu NORP
# Hindus NORP
# Hindus NORP
# India GPE
# winter DATE
# spring DATE
# Afghanistan GPE
# Hamun ORG
# Reeds ORG
# Hamun ORG
# last year's DATE
# several yards QUANTITY
# four inches QUANTITY
# fourteen CARDINAL
# half CARDINAL
# Persian NORP
# twelve miles QUANTITY
# only five or CARDINAL
# six feet QUANTITY
# weeks DATE
# 46 CARDINAL
# 72-81 DATE
# Hamun PERSON
# a couple of hours TIME
# Seistan GPE
# Nasretabad GPE
# Five months DATE
# the morning TIME
# Hamun ORG
# Asia LOC
# Aryans NORP
# Christianity NORP
# Mohammedanism ORG
# the "Black Death WORK_OF_ART
# the year 1350 DATE
# twenty-five millions QUANTITY
# Europe LOC
# 1894 DATE
# China GPE
# Hong Kong GPE
# India GPE
# three millions CARDINAL
# a few years DATE
# the poor quarter DATE
# Bombay GPE
# 1902 DATE
# forty CARDINAL
# 1906 DATE
# Seistan GPE
# English NORP
# hundreds CARDINAL
# English NORP
# Mohammedan PERSON
# Europeans NORP
# Christians NORP
# the British Consulate FAC
# night TIME
# the hyænas and jackals ORG
# twelve hundred CARDINAL
# one CARDINAL
# two CARDINAL
# half CARDINAL
# two days DATE
# a couple of days DATE
# Baluchistan GPE
# India GPE
# Baluchis ORG
# Two CARDINAL
# two CARDINAL
# two CARDINAL
# forty years ago DATE
# Baluchis PERSON
# Persian NORP
# British NORP
# six CARDINAL
# One evening TIME
# Shah Sevar PERSON
# the "Riding King WORK_OF_ART
# Baluchistan NORP
# two CARDINAL
# Shah Sevar PERSON
# two CARDINAL
# three CARDINAL
# Fourteen CARDINAL
# Shah Sevar ORG
# eight days DATE
# the day before yesterday DATE
# Bam GPE
# Bam GPE
# three hundred miles QUANTITY
# four days' DATE
# ten CARDINAL
# their day DATE
# Mount WORK_OF_ART
# Muskets ORG
# Shah Sevar ORG
# the night TIME
# Day DATE
# Bam GPE
# the night TIME
# first ORDINAL
# seventy miles QUANTITY
# the Spring of White Water EVENT
# the hot hours of the day TIME
# the first night TIME
# spring DATE
# third ORDINAL
# Bam GPE
# all day DATE
# ten or twelve miles QUANTITY
# Shah Sevar ORG
# Bam GPE
# four CARDINAL
# The day DATE
# Shah Sevar ORG
# nine o'clock TIME
# an hour TIME
# Bam GPE
# Baluchi ORG
# Shah Sevar PERSON
# three CARDINAL
# only three miles QUANTITY
# Bam GPE
# Shah Sevar ORG
# three CARDINAL
# twelve CARDINAL
# six CARDINAL
# two CARDINAL
# two CARDINAL
# Shah Sevar PERSON
# Twenty-three CARDINAL
# Three CARDINAL
# Shah Sevar ORG
# Riding King WORK_OF_ART
# Bam GPE
# Bam GPE
# twelve CARDINAL
# ten CARDINAL
# Sixteen CARDINAL
# half an hour TIME
# this night TIME
# all night TIME
# first ORDINAL
# a minute TIME
# half CARDINAL
# Bam. GPE
# eight days DATE
# Persia GPE
# Turkomans NORP
# Khorasan PERSON
# Kurds NORP
# Baluchistan NORP
# the end of April DATE
# every day DATE
# 105-1/2 CARDINAL
# Baluchis PERSON
# mid-day DATE
# night TIME
# Baluchistan NORP
# Persia GPE
# five CARDINAL
# About two hundred CARDINAL
# six inches QUANTITY
# Baluchistan GPE
# seven CARDINAL
# six CARDINAL
# thirteenth ORDINAL
# two CARDINAL
# night TIME
# the first day DATE
# Cases ORG
# twelve hours TIME
# Asiatic GPE
# one CARDINAL
# Eastern Turkestan LOC
# 1500 miles QUANTITY
# Nushki PERSON
# 132 CARDINAL
# Indian NORP
# Baluchi ORG
# Quetta GPE
# one CARDINAL
# Karachi ORG
# British NORP
# India GPE
# Rawalpindi GPE
# Kashmir LOC
# Baluchistan GPE
# nearly 107 CARDINAL
# half CARDINAL
# European NORP
# two CARDINAL
# Thereby ORG
# twenty degrees QUANTITY
# Himalayas LOC
# Indian NORP
# the Indian Ocean LOC
# three CARDINAL
# India GPE
# Ganges PERSON
# Bramaputra PERSON
# Tibet GPE
# Ganges PRODUCT
# Bramaputra PERSON
# the Bay of Bengal LOC
# the Arabian Sea LOC
# Bramaputra PERSON
# Tibet GPE
# Himalayas ORG
# two CARDINAL
# as much as MONEY
# Bramaputra PERSON
# Sutlej ORG
# Punjab ORG
# Persian NORP
# five CARDINAL
# thirteen CARDINAL
# 150 miles QUANTITY
# 2000 miles QUANTITY
# Danube ORG
# the month of July DATE
# 325 years DATE
# Christ ORG
# Aristotle PERSON
# Alexander ORG
# Macedonia GPE
# Pattala GPE
# twenty years of age DATE
# Macedonia GPE
# Thrace GPE
# Illyria GPE
# Greece GPE
# Hellespont GPE
# Persians NORP
# Asia Minor GPE
# Lycia, Cappadocia PERSON
# Phrygia ORG
# Gordian NORP
# Asia LOC
# Cyprus PRODUCT
# Persia GPE
# Darius Codomannus PERSON
# the united forces of his ORG
# Damascus GPE
# Persian NORP
# Phoenicians NORP
# Tyre GPE
# Sidon GPE
# Palestine GPE
# Jerusalem GPE
# Egypt GPE
# Alexandria PERSON
# 2240 years DATE
# Libyan NORP
# Zeus Ammon PERSON
# Pharaonic ORG
# Son of Ammon WORK_OF_ART
# Asia LOC
# Euphrates ORG
# Darius ORG
# Tigris GPE
# Babylon PERSON
# Shushan GPE
# 150 years DATE
# King Ahasuerus PERSON
# India GPE
# Ethiopia GPE
# an hundred and seven CARDINAL
# twenty CARDINAL
# Persepolis GPE
# the Great King FAC
# Darius PERSON
# Ispahan GPE
# Hamadan GPE
# Bactria GPE
# Russian Central Asia LOC
# Scythians ORG
# more than a hundred thousand CARDINAL
# Punjab PRODUCT
# Pattala GPE
# Greeks PERSON
# Macedonians NORP
# Babylon ORG
# Teheran GPE
# Tebbes GPE
# Seistan GPE
# Baluchistan GPE
# Seistan GPE
# Persia GPE
# forty thousand CARDINAL
# Twelve thousand CARDINAL
# the Arabian Sea LOC
# Straits LOC
# Hormuz ORG
# the Persian Gulf LOC
# Euphrates LOC
# Greek NORP
# Alexander ORG
# Euphrates LOC
# 40,000 CARDINAL
# this march DATE
# no less than 30,000 CARDINAL
# Nearchus of Crete ORG
# the present day DATE
# Alexander ORG
# thirty CARDINAL
# 150 CARDINAL
# three CARDINAL
# summer DATE
# the second day DATE
# Alexander ORG
# Eventually Alexander PERSON
# Alexander ORG
# the present day DATE
# Alexander PERSON
# Ammon PERSON
# first ORDINAL
# Next day DATE
# Alexander PERSON
# Poseidon PERSON
# Nereids GPE
# Thetis PRODUCT
# Achilles GPE
# Euphrates ORG
# Alexander ORG
# the age of thirty-three DATE
# Greek NORP
# Asia LOC
# the night TIME
# first ORDINAL
# 180 miles QUANTITY
# Srinagar GPE
# Kashmir LOC
# two CARDINAL
# two CARDINAL
# every half hour TIME
# India GPE
# the Jhelum River LOC
# Srinagar GPE
# Jhelum River LOC
# Kashmiris GPE
# Kashmir LOC
# Indian NORP
# about three millions CARDINAL
# Kashmir LOC
# Round ORG
# Kashmir valley LOC
# Himalayas ORG
# one CARDINAL
# thirty-six QUANTITY
# hundred CARDINAL
# some 250 miles QUANTITY
# Two days later DATE
# Leh CARDINAL
# nearly 11,500 feet QUANTITY
# bazaar street ORG
# Leh CARDINAL
# Ladak GPE
# Kashmir LOC
# Tibetan NORP
# 1895 DATE
# India GPE
# Eastern Turkestan LOC
# month DATE
# Yarkand GPE
# Eastern Turkestan LOC
# Tibet GPE
# India GPE
# China GPE
# Pamir ORG
# Roof of the World WORK_OF_ART
# two CARDINAL
# the Sea of Aral LOC
# Mountains of Heaven ORG
# Altai PERSON
# Siberia LOC
# Asia LOC
# Eastern Turkestan LOC
# Tibetan NORP
# Tarim ORG
# Yarkand ORG
# Khotan NORP
# Eastern Turkestan LOC
# Tarim ORG
# Lop-nor ORG
# two CARDINAL
# Eastern Turkestan LOC
# 89 CARDINAL
# Asia LOC
# Africa LOC
# Gobi PERSON
# Mongolia GPE
# Takla ORG
# the "Black Sand WORK_OF_ART
# Russian NORP
# Kevir PERSON
# Persia GPE
# Arabia GPE
# Sahara LOC
# the Old World EVENT
# the Pacific Ocean LOC
# Atlantic LOC
# Takla ORG
# the beginning of April, 1895 DATE
# Yarkand ORG
# Merket GPE
# Takla ORG
# Khotan NORP
# 180 miles QUANTITY
# four CARDINAL
# eight CARDINAL
# two months DATE
# Tibet GPE
# twenty-five days DATE
# four CARDINAL
# April 10 DATE
# Muhamed Shah PERSON
# Kasim GPE
# Islam Bay FAC
# two CARDINAL
# Yolldash PERSON
# Hamra ORG
# three CARDINAL
# ten CARDINAL
# the first few days DATE
# April 18 DATE
# Next day DATE
# geese NORP
# day DATE
# a day DATE
# four days' DATE
# Khotan NORP
# ten days DATE
# April 23 DATE
# as much as 100 feet MONEY
# The next day DATE
# Islam Bay ORG
# only eight miles QUANTITY
# the morning of the 25th TIME
# two CARDINAL
# two CARDINAL
# two days DATE
# One CARDINAL
# Old Man PRODUCT
# an hour TIME
# Muhamed Shah. PERSON
# Islam ORG
# the night of the 26th TIME
# about two CARDINAL
# daily DATE
# three days DATE
# The next day DATE
# 200 feet QUANTITY
# two CARDINAL
# the beginning of the day DATE
# two CARDINAL
# April 28 DATE
# night TIME
# two CARDINAL
# third ORDINAL
# evening TIME
# two CARDINAL
# next morning TIME
# Islam ORG
# one CARDINAL
# all day DATE
# the morning of the 30th TIME
# less than two-thirds CARDINAL
# Islam ORG
# Islam ORG
# Only one-third CARDINAL
# mid-day DATE
# the evening TIME
# Kasim GPE
# Muhamed PERSON
# May 1 DATE
# the day before DATE
# Thirst ORG
# one CARDINAL
# Chinese NORP
# Muhamed Shah PERSON
# Kasim GPE
# Islam ORG
# Plate PERSON
# the white camel ORG
# two CARDINAL
# European NORP
# evening TIME
# mid-day DATE
# Islam ORG
# Mecca GPE
# Yolldash PERSON
# Muhamed Shah PERSON
# seven o'clock TIME
# Islam ORG
# Kasim GPE
# earth LOC
# Islam ORG
# half CARDINAL
# Kasim GPE
# two CARDINAL
# ten CARDINAL
# twelve o'clock TIME
# Islam Bay LOC
# Kasim GPE
# Russian NORP
# Swedish NORP
# two hours TIME
# four o'clock TIME
# nine CARDINAL
# twelve o'clock TIME
# the day DATE
# Kasim GPE
# six o'clock TIME
# seven hours TIME
# one o'clock TIME
# quite three hours TIME
# The next day DATE
# May 3 DATE
# Kasim GPE
# half-past nine DATE
# bush PERSON
# quite nine hours TIME
# three hours TIME
# Kasim GPE
# three CARDINAL
# Islam ORG
# Khotan LOC
# four o'clock TIME
# May 4 DATE
# five hours TIME
# Kasim GPE
# ten hours TIME
# Kasim GPE
# Just after midnight TIME
# Kasim GPE
# the day DATE
# Kasim GPE
# May 5 DATE
# half an hour TIME
# four o'clock TIME
# Kasim GPE
# Khotan LOC
# poplars PERSON
# morning TIME
# nine o'clock TIME
# the day DATE
# Kasim GPE
# ten hours TIME
# seven o'clock TIME
# Kasim GPE
# Khotan LOC
# the summer DATE
# a mile QUANTITY
# Hitherto PERSON
# this night TIME
# forty-nine CARDINAL
# first ORDINAL
# a few minutes TIME
# fifty-six CARDINAL
# fifty CARDINAL
# six miles QUANTITY
# Kasim GPE
# Kasim PERSON
# the middle of the day DATE
# Kasim GPE
# Kasim GPE
# a week DATE
# some days ago DATE
# Kasim GPE
# nine o'clock TIME
# three hours TIME
# half an hour TIME
# May 1 DATE
# the night TIME
# a couple of hours TIME
# May 7 DATE
# a few hours my feet TIME
# noon TIME
# again hour after hour TIME
# eight o'clock TIME
# poplars ORG
# May 8 DATE
# the hot hours of the day TIME
# two CARDINAL
# four CARDINAL
# first ORDINAL
# ewe GPE
# three CARDINAL
# next day DATE
# Islam Bay ORG
# Kasim GPE
# Merket GPE
# Takla ORG
# 1895 DATE
# September, 1899 DATE
# Eastern Turkestan LOC
# Yarkand ORG
# Tarim ORG
# one CARDINAL
# more than a thousand miles CARDINAL
# Plate X. PERSON
# 36 feet QUANTITY
# 8-1/2 CARDINAL
# two CARDINAL
# AUTHOR ORG
# Islam Bay ORG
# Islam Bay FAC
# nine inches QUANTITY
# Fruit ORG
# three months' DATE
# September 17, 1899 DATE
# seven CARDINAL
# Islam Bay LOC
# Kader ORG
# Islam Bay PERSON
# Palta ORG
# two CARDINAL
# one CARDINAL
# Kasim GPE
# two CARDINAL
# four CARDINAL
# Dovlet ORG
# Yolldash PERSON
# Dovlet ORG
# Yolldash WORK_OF_ART
# Takla ORG
# Palta ORG
# day DATE
# Dovlet ORG
# Yolldash PERSON
# Islam Bay ORG
# Islam ORG
# a few days DATE
# Palta ORG
# the latter days of DATE
# September DATE
# Weeks DATE
# Autumn GPE
# earlier in the morning TIME
# each day DATE
# Islam ORG
# one CARDINAL
# One morning TIME
# two CARDINAL
# TARIM ORG
# Yarkand ORG
# Lop-nor ORG
# White Water WORK_OF_ART
# Tarim ORG
# One morning TIME
# Breakfast LOC
# two CARDINAL
# Chinese NORP
# as much as 200 feet MONEY
# Eastern Turkestan LOC
# Lopliks ORG
# the last few days DATE
# November DATE
# 28 CARDINAL
# 8 CARDINAL
# one morning TIME
# all day DATE
# the nights DATE
# December 7 DATE
# WANDERING ORG
# the winter DATE
# New Lake LOC
# 90 CARDINAL
# Tarim ORG
# Lop-nor ORG
# Lop-nor ORG
# Chinese NORP
# Lop-nor ORG
# Tarim ORG
# Lop PERSON
# Chinese NORP
# more than 1600 years old DATE
# Tarim ORG
# Tarim ORG
# year to DATE
# Tarim ORG
# hundreds of years DATE
# Turkish NORP
# Islam ORG
# geese NORP
# six feet QUANTITY
# Tigers ORG
# half a dozen CARDINAL
# one CARDINAL
# canoe ORG
# canoe ORG
# third ORDINAL
# first ORDINAL
# Lop-nor ORG
# winter DATE
# summer DATE
# winter DATE
# 22° below zero QUANTITY
# summer DATE
# 104 CARDINAL
# Africa LOC
# summer DATE
# winter DATE
# winter DATE
# summer DATE
# night TIME
# the day DATE
# geese NORP
# Lop-nor ORG
# late autumn TIME
# Tibet GPE
# winter DATE
# thousands of years DATE
# Lop PERSON
# Lop PERSON
# Chinese NORP
# the "Dry Mountains EVENT
# half a dozen CARDINAL
# two CARDINAL
# spring DATE
# summer DATE
# eight days DATE
# winter DATE
# two weeks DATE
# twelve miles QUANTITY
# one CARDINAL
# two minutes TIME
# two CARDINAL
# one CARDINAL
# eleven days DATE
# 1901-2 DATE
# 1906 DATE
# TIBET
# South GPE
# Eastern Turkestan LOC
# earth LOC
# Tibet GPE
# China GPE
# Burma GPE
# Bhutan GPE
# Sikkim GPE
# Nepal GPE
# British India ORG
# Kashmir LOC
# Ladak GPE
# century to century DATE
# Tibet GPE
# Tibet GPE
# Pamir ORG
# Tibet GPE
# Himalayas ORG
# Karakorum ORG
# third ORDINAL
# Arka ORG
# five CARDINAL
# Karakorum PERSON
# Tibetan GPE
# Tibet GPE
# two CARDINAL
# the Yellow River LOC
# the Hwang-ho LOC
# the Yellow Sea LOC
# the Blue River LOC
# Yang PERSON
# the Eastern Sea LOC
# Mekong ORG
# the China Sea LOC
# Salwin PERSON
# Irawaddy PERSON
# Brahmaputra ORG
# the Indian Ocean LOC
# the Bay of Bengal FAC
# Ganges PERSON
# Himalayas LOC
# two CARDINAL
# the Arabian Sea LOC
# Tarim ORG
# Lop-nor ORG
# Himalayas LOC
# Three CARDINAL
# Mount Everest LOC
# 29,000 feet QUANTITY
# Kinchinjunga GPE
# 28,200 feet QUANTITY
# Dhwalagiri ORG
# 26,800 feet QUANTITY
# Mount Godwin-Austen PERSON
# Karakorum PERSON
# only about 650 feet QUANTITY
# Mount Everest LOC
# Himalayas ORG
# Calcutta ORG
# Sikkim PERSON
# Himalayas LOC
# Kinchinjunga GPE
# early in the morning TIME
# snowy crest ORG
# South Italy LOC
# the North Cape LOC
# North and Central Tibet ORG
# 16,000 feet QUANTITY
# Blanc PRODUCT
# five CARDINAL
# west. GPE
# Asia LOC
# Tibet GPE
# India GPE
# Eastern Turkestan LOC
# Asia LOC
# Arabia GPE
# Asia LOC
# Europe LOC
# Asia LOC
# Asia LOC
# Europe LOC
# Africa LOC
# Australia GPE
# 1550 DATE
# 830 millions CARDINAL
# more than half CARDINAL
# Asia LOC
# Europe LOC
# Asia LOC
# three CARDINAL
# Spain GPE
# Portugal GPE
# the Arabian Peninsula LOC
# Italy GPE
# the Indian Peninsula LOC
# Sicily GPE
# Ceylon ORG
# Balkan Peninsula LOC
# India GPE
# Archipelago LOC
# Tibet GPE
# Himalayas LOC
# two CARDINAL
# the Upper Indus FAC
# the Upper Brahmaputra LOC
# Tibet GPE
# China GPE
# Europeans NORP
# Tibet GPE
# third ORDINAL
# three months DATE
# eighty-one days DATE
# Tibet GPE
# two or three million CARDINAL
# Brahmaputra ORG
# Lhasa GPE
# Shigatse GPE
# India GPE
# Buddha PERSON
# Tibet GPE
# a thousand years ago DATE
# 620 millions CARDINAL
# Christians NORP
# 400 million CARDINAL
# Buddhists NORP
# Tibetans NORP
# Mongolians ORG
# Buriats NORP
# Siberia LOC
# Kalmukhs NORP
# Volga ORG
# Ladak GPE
# Nepal GPE
# Sikkim GPE
# Bhutan GPE
# Lhasa GPE
# Tashi ORG
# Tashi ORG
# Shigatse ORG
# third ORDINAL
# Mongolia GPE
# three CARDINAL
# Lhasa GPE
# Nirvana GPE
# Brahmaputra ORG
# two CARDINAL
# Mohammedans NORP
# the year 1901 DATE
# third ORDINAL
# The summer DATE
# sixteen CARDINAL
# Mohammedan ORG
# Eastern Turkestan LOC
# two CARDINAL
# Russian NORP
# two CARDINAL
# Buriat Cossacks PERSON
# Urga ORG
# seven months DATE
# 39 CARDINAL
# 45 CARDINAL
# 60 CARDINAL
# 50 CARDINAL
# one CARDINAL
# more than twelve miles QUANTITY
# a day DATE
# forty-four days' DATE
# Lhasa PERSON
# only 300 miles QUANTITY
# Europeans NORP
# Tibetan NORP
# Tibetans NORP
# European NORP
# India GPE
# Central Asia LOC
# Tibet GPE
# Two hundred years ago DATE
# Catholic NORP
# Lhasa GPE
# 1845 DATE
# Huc GPE
# Gabet GPE
# France GPE
# two CARDINAL
# Europeans NORP
# only two CARDINAL
# One CARDINAL
# the Buriat Cossack, Shagdur ORG
# Mongol NORP
# Mongolian ORG
# European NORP
# two CARDINAL
# Russian NORP
# Swedish NORP
# five CARDINAL
# four CARDINAL
# two CARDINAL
# Tiger and Lilliput WORK_OF_ART
# Shagdur PERSON
# the first two days DATE
# Mohammedan PERSON
# Ördek GPE
# Lhasa GPE
# Mongolians NORP
# Tashi ORG
# Lamaist PERSON
# July 27 DATE
# The first day DATE
# the second day DATE
# twenty-five miles QUANTITY
# two CARDINAL
# Ördek GPE
# the night TIME
# Lama PERSON
# two CARDINAL
# Lamaist NORP
# the afternoon TIME
# midnight TIME
# Ördek GPE
# two CARDINAL
# two CARDINAL
# Shagdur ORG
# Shagdur PRODUCT
# First ORDINAL
# One CARDINAL
# two CARDINAL
# Tibetan GPE
# third ORDINAL
# all day DATE
# Lhasa GPE
# Ördek GPE
# the two days' DATE
# night TIME
# Ördek GPE
# two whole days DATE
# three CARDINAL
# twenty-five miles QUANTITY
# Shagdur PERSON
# Russian NORP
# eight o'clock TIME
# two CARDINAL
# three CARDINAL
# Tibetan NORP
# three CARDINAL
# nine o'clock to midnight TIME
# three o'clock to six o'clock TIME
# first ORDINAL
# Tiger PERSON
# half-past eight DATE
# Shagdur PERSON
# first ORDINAL
# Tiger and Lilliput WORK_OF_ART
# Mongolian NORP
# midnight TIME
# Shagdur PERSON
# half an hour TIME
# Shagdur PERSON
# Next day DATE
# nomad ORG
# hourly TIME
# Tibetans NORP
# July 31 DATE
# Tangut ORG
# fifty CARDINAL
# two CARDINAL
# three CARDINAL
# Tanguts PERSON
# Tibet GPE
# second ORDINAL
# Tangut ORG
# first ORDINAL
# Tibetan NORP
# two CARDINAL
# Sampo Singi PERSON
# Tibetan NORP
# Sampo Singi PERSON
# eight days DATE
# Lhasa GPE
# Shagdur PERSON
# at least fifty CARDINAL
# Shagdur PERSON
# Early in the morning TIME
# Sampo PERSON
# Chinese NORP
# Sampo Singi PERSON
# Lhasa GPE
# two CARDINAL
# Chinese NORP
# Turkestan GPE
# Tibetans NORP
# Tibetans NORP
# about twenty CARDINAL
# four CARDINAL
# Lama PERSON
# Shagdur PERSON
# about half CARDINAL
# two CARDINAL
# swung round ORG
# two CARDINAL
# a minute after midnight TIME
# Shagdur PERSON
# August 2 DATE
# only fifteen and a CARDINAL
# twenty-five CARDINAL
# three hundred CARDINAL
# Chinese NORP
# about twenty CARDINAL
# next morning TIME
# Persia GPE
# Turkestan GPE
# thirty or forty CARDINAL
# ten CARDINAL
# the next day DATE
# August 4 DATE
# about a hundred CARDINAL
# fourteen CARDINAL
# one CARDINAL
# Lhasa GPE
# The next day DATE
# twelve CARDINAL
# Three CARDINAL
# Tibetans NORP
# dusk TIME
# Tibetan GPE
# One CARDINAL
# three CARDINAL
# European NORP
# one CARDINAL
# the morning TIME
# All night TIME
# next day DATE
# Province GPE
# the following days DATE
# the Dalai Lama LOC
# daily DATE
# Lhasa GPE
# seven CARDINAL
# Tibetans NORP
# August 9 DATE
# Tibetans NORP
# The Governor WORK_OF_ART
# Kamba Bombo PERSON
# Greet Kamba Bombo WORK_OF_ART
# first ORDINAL
# one CARDINAL
# Kamba PERSON
# Kamba Bombo PERSON
# Lhasa GPE
# Two hours later TIME
# Tibetans NORP
# forty years old DATE
# Chinese NORP
# Lhasa GPE
# that day DATE
# Tibet GPE
# TASHI ORG
# Leh CARDINAL
# Ladak GPE
# winter DATE
# Eastern Turkestan LOC
# Kashmir LOC
# several years DATE
# August, 1906 DATE
# Europe LOC
# the Black Sea LOC
# Persia GPE
# Baluchistan GPE
# Rawalpindi GPE
# Kashmir LOC
# Leh CARDINAL
# twenty-seven CARDINAL
# nearly a hundred CARDINAL
# thirty CARDINAL
# Tibet GPE
# eighty-one days DATE
# Tibetan NORP
# one CARDINAL
# about six months DATE
# the Upper Brahmaputra LOC
# Tibetans NORP
# four CARDINAL
# day DATE
# Shigatse GPE
# second ORDINAL
# Tibet GPE
# two CARDINAL
# Tibetan GPE
# Brahmaputra ORG
# Shigatse GPE
# Two days later DATE
# the New Year EVENT
# Round ORG
# Tibet GPE
# TASHI-LUNPO ORG
# Author ORG
# Tibetans NORP
# four CARDINAL
# lotus ORG
# Buddha PERSON
# lotus ORG
# four CARDINAL
# Tashi ORG
# Plate XI PERSON
# 3800 CARDINAL
# Tashi ORG
# Tibet GPE
# the Dalai Lama LOC
# Lhasa GPE
# hours TIME
# Tashi ORG
# twenty-seven years of age DATE
# New Year's Day EVENT
# Round ORG
# Tashi ORG
# ten feet QUANTITY
# the New Year EVENT
# Israel GPE
# the year DATE
# Tibet GPE
# Chinese NORP
# The next day DATE
# Tashi ORG
# Tashi ORG
# several hours TIME
# Tibet GPE
# Sweden GPE
# Tibet GPE
# many thousands CARDINAL
# several hundred CARDINAL
# Latin NORP
# Equus kiang PERSON
# kiang WORK_OF_ART
# Tibet GPE
# Tibet GPE
# one CARDINAL
# two CARDINAL
# India GPE
# Tibet GPE
# Tibetan GPE
# European NORP
# winter DATE
# Singular ORG
# several days DATE
# about 15,000 feet QUANTITY
# 3000 feet QUANTITY
# less than half CARDINAL
# one CARDINAL
# several days DATE
# only two CARDINAL
# One CARDINAL
# Afghan NORP
# Aldat GPE
# Eastern Turkestan LOC
# about 600 feet QUANTITY
# Blanc PRODUCT
# Aldat GPE
# Aldat GPE
# thirty CARDINAL
# fifteen years DATE
# an hour TIME
# September 9 DATE
# the 23rd of the same month DATE
# Aldat ORG
# TIBET GPE
# Tibet GPE
# Sutlej ORG
# Himalayas LOC
# Tibet GPE
# India GPE
# Himalayas ORG
# Marco Polo's PERSON
# India GPE
# Tibet GPE
# 13,000 feet QUANTITY
# 12,000 feet QUANTITY
# Between 10,000 and 6000 feet CARDINAL
# Himalayan NORP
# Lebanon GPE
# 7000 feet QUANTITY
# 3500 feet QUANTITY
# Indian NORP
# Sutlej NORP
# the early morning TIME
# Tibet GPE
# One CARDINAL
# Tibetan GPE
# one fine day DATE
# Tibet GPE
# first ORDINAL
# Simla PERSON
# Plate XII ORG
# 15,000 CARDINAL
# one CARDINAL
# Imperial ORG
# the King of England ORG
# India GPE
# Viceroy GPE
# summer DATE
# India GPE
# Europeans NORP
# Viceroy PRODUCT
# Simla PERSON
# London GPE
# this season DATE
# 30,000 CARDINAL
# Simla PERSON
# Round ORG
# Punjab PRODUCT
# Sutlej ORG
# Himalayas LOC
# Simla PERSON
# India GPE
# Simla PERSON
# Tibet GPE
# DELHI ORG
# AGRA ORG
# Simla PERSON
# hundreds CARDINAL
# Punjab ORG
# Tibet GPE
# Time ORG
# Delhi GPE
# one CARDINAL
# Ganges PERSON
# Delhi GPE
# the Great Moguls FAC
# the seventeenth century DATE
# INDIA GPE
# pp. GPE
# 82 CARDINAL
# TIBET GPE
# ETC ORG
# TO BOMBAY PERSON
# 130 CARDINAL
# the Hall of Private Audience FAC
# the Great Mogul FAC
# the Great Mogul EVENT
# the year 1749 DATE
# Persian NORP
# Nadir Shah PERSON
# Delhi GPE
# the Great Mogul EVENT
# fifty-six million pounds QUANTITY
# the "Koh-i-noor WORK_OF_ART
# Mountain of Light WORK_OF_ART
# British NORP
# the Peacock Throne ORG
# eleven million pounds MONEY
# this day DATE
# Persia GPE
# Nadir Shah ORG
# some hours TIME
# Delhi GPE
# Hindus NORP
# Mohammedans NORP
# the Hall of Private Audience ORG
# Persian NORP
# Jumna PERSON
# Agra PERSON
# Agra PERSON
# Great Mogul ORG
# the seventeenth century DATE
# Shah Jehan PERSON
# Plate XIII ORG
# the "Taj Mahal PRODUCT
# royal palace WORK_OF_ART
# Shah Jehan's PERSON
# Mumtaz PERSON
# twenty-seven years DATE
# nearly two million pounds MONEY
# lotus blossoms ORG
# Taj Mahal GPE
# earth LOC
# four CARDINAL
# 240 feet QUANTITY
# Shah Jehan PERSON
# Mumtaz PERSON
# four CARDINAL
# evening TIME
# Steamy ORG
# Jumna PERSON
# Ganges PERSON
# Ganges PERSON
# 100 million CARDINAL
# Hindus NORP
# two or three thousand years old DATE
# Hindu NORP
# Jerusalem GPE
# Rome GPE
# Mecca GPE
# Lhasa GPE
# Benares PERSON
# India GPE
# Brahminism NORP
# more than 200 millions CARDINAL
# Hindus NORP
# Benares PERSON
# Hindus NORP
# Ganges PERSON
# Benares PERSON
# Buddha PERSON
# 500 years DATE
# the present day DATE
# more than 400 million CARDINAL
# Buddhists NORP
# Benares PERSON
# Hindus NORP
# three CARDINAL
# Vishnu ORG
# Siva ORG
# Kali PERSON
# only one CARDINAL
# Siva ORG
# British NORP
# Hindus NORP
# eagles GPE
# Hindu NORP
# thousands of years DATE
# India GPE
# Persia GPE
# Hindustan ORG
# Aryans NORP
# quite 4000 years ago DATE
# Hindus NORP
# Europe LOC
# the Middle Ages EVENT
# two CARDINAL
# Brahmins PERSON
# thousand CARDINAL
# Early in the morning TIME
# the day DATE
# Ganges PERSON
# Plate XIV ORG
# about 100 feet QUANTITY
# half CARDINAL
# Ganges PERSON
# Vishnu ORG
# twenty-four CARDINAL
# Vishnu ORG
# Brahma ORG
# Vishnu ORG
# Siva ORG
# sun GPE
# moon PERSON
# Ganges PERSON
# thousands CARDINAL
# 108 CARDINAL
# Vishnu ORG
# the afternoon TIME
# evening TIME
# Benares PERSON
# Vishnu ORG
# Benares PERSON
# Benares PERSON
# Buddhists NORP
# Hindus NORP
# Hindu ORG
# more than eight million CARDINAL
# this short morning hour TIME
# Ganges ORG
# second ORDINAL
# the evening TIME
# the hottest hours of the day TIME
# Benares PRODUCT
# Noiseless ORG
# half CARDINAL
# the sixth century DATE
# Aryan PERSON
# Sakya PERSON
# Kapilavastu GPE
# 120 miles QUANTITY
# Benares GPE
# Siddharta GPE
# his eighteenth year DATE
# Yasodara GPE
# First ORDINAL
# Siddharta GPE
# Siddharta GPE
# second ORDINAL
# Siddharta GPE
# two CARDINAL
# Siddharta ORG
# Kapilavastu GPE
# one day DATE
# the next day DATE
# Siddharta GPE
# first ORDINAL
# Everywhere ORG
# Siddharta GPE
# Yes, Sire WORK_OF_ART
# the night TIME
# Yasodara GPE
# Kapilavastu GPE
# four CARDINAL
# Brahmins PERSON
# Brahma PERSON
# Brahmins PERSON
# five CARDINAL
# Siddharta GPE
# India GPE
# Buddha PERSON
# Benares PERSON
# first ORDINAL
# June to October DATE
# Benares PERSON
# Buddha PERSON
# the age of eighty years DATE
# 480 CARDINAL
# Hindus NORP
# Brahmins PERSON
# Vedic PRODUCT
# Nirvana GPE
# five CARDINAL
# Thou GPE
# To-day DATE
# 2500 years DATE
# Buddha PERSON
# Asia LOC
# Japan GPE
# China GPE
# Korea GPE
# Mongolia GPE
# Tibet GPE
# India GPE
# Ceylon ORG
# the Caspian Sea LOC
# Buddha PERSON
# Asia LOC
# the "Light of Asia. PRODUCT
# Benares PERSON
# Ganges PERSON
# Brahmaputra NORP
# Calcutta ORG
# India GPE
# one CARDINAL
# more than a million CARDINAL
# winter DATE
# about 95 CARDINAL
# Viceroy PRODUCT
# Simla PERSON
# Calcutta ORG
# the Indian Peninsula LOC
# Bombay GPE
# India GPE
# Europe LOC
# the Suez Canal LOC
# about 800,000 CARDINAL
# About six or CARDINAL
# Christ ORG
# Zoroaster PERSON
# Persia GPE
# Xerxes PRODUCT
# Greece GPE
# Islam ORG
# Persia GPE
# 650 A.
# D. DATE
# many thousands CARDINAL
# Zoroaster PERSON
# India GPE
# Bombay GPE
# Bombay GPE
# five CARDINAL
# Bombay GPE
# a few minutes TIME
# India GPE
# Africa LOC
# India GPE
# First ORDINAL
# millions CARDINAL
# India GPE
# Africa LOC
# Mediterranean LOC
# Mexico GPE
# Central America LOC
# about sixty feet QUANTITY
# China GPE
# Cochin China PERSON
# India GPE
# India GPE
# Figs ORG
# the New Testament ORG
# Buddha PERSON
# Ficus ORG
# Nymphæa stellaris GPE
# lotus ORG
# Buddhists NORP
# lotus ORG
# Cross ORG
# Christianity NORP
# India GPE
# Indian NORP
# Bengal GPE
# Burma GPE
# India GPE
# Deccan ORG
# bush PERSON
# Manchester ORG
# India GPE
# Arabia GPE
# bush PERSON
# more than 2000 years DATE
# Alexander the Great ORG
# Greece GPE
# the United States of America GPE
# recent decades DATE
# india GPE
# the year 1830 DATE
# 230 tons QUANTITY
# Europe LOC
# 1896 DATE
# 315,500 tons QUANTITY
# Borneo PERSON
# ten CARDINAL
# Ceylon GPE
# Java PERSON
# India GPE
# Brazilian NORP
# Hevea ORG
# Brazil GPE
# two-thirds CARDINAL
# Europe LOC
# Alexander ORG
# India GPE
# Europe LOC
# Macedonia GPE
# Asia Minor GPE
# Persia GPE
# India GPE
# China GPE
# the end of the seventeenth century DATE
# Chinese NORP
# Persia GPE
# China GPE
# India GPE
# 20 per cent MONEY
# Sanscrit GPE
# India GPE
# Arabs NORP
# Mediterranean LOC
# Europe LOC
# Asia LOC
# an age of twenty years DATE
# India GPE
# 130 feet QUANTITY
# Indian NORP
# Europe LOC
# Indian NORP
# Alexander ORG
# India GPE
# Ceylon GPE
# Sumatra NORP
# Borneo PERSON
# Africa LOC
# thirty or forty CARDINAL
# India GPE
# Expert ORG
# two whole days DATE
# Ceylon ORG
# India GPE
# hundred CARDINAL
# several miles QUANTITY
# nearly ten days DATE
# 12 feet QUANTITY
# 160 feet QUANTITY
# 12 feet QUANTITY
# two CARDINAL
# two CARDINAL
# two CARDINAL
# forty-eight hours TIME
# Plate XV PERSON
# India GPE
# India GPE
# India GPE
# Further India GPE
# China GPE
# Ceylon ORG
# about five feet QUANTITY
# eight CARDINAL
# one CARDINAL
# Hindus NORP
# one CARDINAL
# About twenty thousand CARDINAL
# annually DATE
# India GPE
# several hours TIME
# a couple of hours TIME
# first ORDINAL
# second ORDINAL
# third ORDINAL
# about ten days DATE
# Indian NORP
# two whole days DATE
# India GPE
# Benares PERSON
# Benares PRODUCT
# One CARDINAL
# five minutes TIME
# India GPE
# Courage ORG
# Europeans NORP
# two CARDINAL
# three CARDINAL
# second ORDINAL
# Viverridæ FAC
# Kipling's Jungle Book ORG
# two CARDINAL
# XI
# FROM INDIA TO CHINA ORG
# 1908 DATE
# INDIAN NORP
# October 14, 1908 DATE
# Bombay GPE
# Delhi GPE
# Shanghai GPE
# Delhi GPE
# 495 feet QUANTITY
# 8000 tons QUANTITY
# Oriental Steam Navigation Company ORG
# the P.
# & O. ORG
# annual DATE
# India GPE
# Australia GPE
# about an hour TIME
# Bombay GPE
# the Indian Ocean LOC
# a couple of hours TIME
# the Western Ghâts LOC
# India GPE
# Next morning TIME
# Goa PERSON
# noon TIME
# Laccadive NORP
# India GPE
# the morning of TIME
# October 17 DATE
# India GPE
# Cape Comorin GPE
# Ceylon PRODUCT
# Asiatic GPE
# European NORP
# Colombo PERSON
# Ceylon ORG
# Europe LOC
# the Far East LOC
# Delhi GPE
# Singalese NORP
# Hindus NORP
# two CARDINAL
# half CARDINAL
# Europeans NORP
# The next day DATE
# Moldavia PERSON
# the P.
# & O. ORG
# England GPE
# Delhi GPE
# the Far East LOC
# Moldavia GPE
# two weeks DATE
# Australia GPE
# Delhi GPE
# Moldavia GPE
# Ceylon ORG
# Sumatra NORP
# 1000 miles QUANTITY
# the morning of TIME
# October 21 DATE
# Two CARDINAL
# summer DATE
# Sumatra NORP
# Asia LOC
# three CARDINAL
# Europe LOC
# Africa LOC
# Australia GPE
# Asia LOC
# America GPE
# Europe LOC
# Asia LOC
# Africa LOC
# Asia LOC
# 70 miles QUANTITY
# 1869 DATE
# the Suez Canal LOC
# Australia GPE
# Asia LOC
# two CARDINAL
# Philippines GPE
# New Guinea GPE
# Sumatra NORP
# first ORDINAL
# Peninsula LOC
# Java PERSON
# five feet QUANTITY
# Sunda Islands GPE
# 4000 CARDINAL
# 5000 feet QUANTITY
# Sumatra NORP
# Borneo PERSON
# summer DATE
# Sunda Islands GPE
# one CARDINAL
# Malays DATE
# Mohammedanism ORG
# Sunda GPE
# four CARDINAL
# Sumatra NORP
# Java PERSON
# Borneo PERSON
# Celebes LOC
# Java PERSON
# one CARDINAL
# England GPE
# Wales GPE
# about 30 millions CARDINAL
# Sumatra NORP
# Delhi GPE
# three CARDINAL
# Java PERSON
# only one-seventh CARDINAL
# Celebes LOC
# about half CARDINAL
# Sumatra NORP
# Borneo PERSON
# third ORDINAL
# about 300,000 square miles QUANTITY
# Holland GPE
# Borneo PERSON
# England GPE
# Sumatra NORP
# Java PERSON
# Krakatau GPE
# the summer of 1883 DATE
# one CARDINAL
# Sumatra NORP
# two CARDINAL
# a few miles QUANTITY
# August 26 DATE
# three feet QUANTITY
# The next day DATE
# 100 feet QUANTITY
# Sumatra NORP
# Java PERSON
# Africa LOC
# America GPE
# Ceylon GPE
# Australia GPE
# 2000 miles QUANTITY
# Vienna GPE
# Europe LOC
# France GPE
# 40,000 CARDINAL
# SINGAPORE GPE
# Delhi GPE
# Penang GPE
# Peninsula LOC
# Penang GPE
# the south coast LOC
# Asia LOC
# the Botanical Gardens FAC
# India GPE
# Sunda Islands GPE
# Australia GPE
# English LANGUAGE
# Monkeys NORP
# Darkness PRODUCT
# a few moments TIME
# Delhi GPE
# the Strait of Malacca LOC
# Singapore GPE
# only thirty hours TIME
# Peninsula LOC
# October 24 DATE
# Singapore GPE
# Great Britain GPE
# nearly a quarter DATE
# million CARDINAL
# Europeans NORP
# Malays DATE
# Indians NORP
# Chinese NORP
# the Far East LOC
# Singapore GPE
# the Sunda Islands GPE
# the Dutch Archipelago LOC
# one CARDINAL
# three degrees QUANTITY
# between winter and summer DATE
# five o'clock TIME
# Delhi GPE
# Malay NORP
# Delhi GPE
# the Chinese Sea LOC
# Asiatic LOC
# two days DATE
# Cochin-China ORG
# Saigon GPE
# Mekong GPE
# October 27 DATE
# Annam GPE
# several degrees QUANTITY
# between two CARDINAL
# India GPE
# French NORP
# Cambodia GPE
# Cochin-China ORG
# Annam GPE
# Tonkin ORG
# Hanoi GPE
# Tonkin GPE
# French NORP
# Saigon GPE
# Mekong GPE
# French NORP
# about half CARDINAL
# France GPE
# about 20 millions CARDINAL
# India GPE
# Siam GPE
# Mekong GPE
# Salwin PERSON
# Tibet GPE
# about two-thirds CARDINAL
# French NORP
# only 9 million CARDINAL
# Siamese NORP
# Chinese NORP
# Malays ORG
# Laos GPE
# Bangkok GPE
# the King of Siam LOC
# half a million CARDINAL
# Buddha PERSON
# Buddhist NORP
# Siam GPE
# Siamese NORP
# Mongolian NORP
# the morning of TIME
# October 29 DATE
# Hong Kong GPE
# Delhi GPE
# noon TIME
# Hong Kong GPE
# English LANGUAGE
# Chinese NORP
# Japanese NORP
# American NORP
# German NORP
# the harbour basin LOC
# Victoria GPE
# Hong Kong GPE
# 440,000 CARDINAL
# Chinese NORP
# five CARDINAL
# the Far East--Gibraltar LOC
# Aden GPE
# Colombo GPE
# Singapore GPE
# Hong Kong GPE
# England GPE
# Hong Kong GPE
# British NORP
# 1842 DATE
# Vessels PRODUCT
# nearly 20 millions CARDINAL
# Hong Kong GPE
# annually DATE
# London GPE
# Hamburg GPE
# New York GPE
# Hong Kong GPE
# Asia LOC
# America GPE
# Europe LOC
# Australia GPE
# the Royal Navy ORG
# Ninety miles QUANTITY
# Hong Kong GPE
# second ORDINAL
# China GPE
# Canton GPE
# Plate XVI ORG
# two CARDINAL
# Canton GPE
# Shanghai GPE
# Chinese NORP
# Canton GPE
# Canton GPE
# one CARDINAL
# Chinese NORP
# 900,000 CARDINAL
# eighteen CARDINAL
# China GPE
# 1200 miles QUANTITY
# Canton GPE
# Peking GPE
# XII ORG
# Hong Kong GPE
# Delhi GPE
# Chinese NORP
# next day DATE
# October 31 DATE
# Formosa GPE
# Japan GPE
# sixteen years ago DATE
# Wales GPE
# the China Sea LOC
# the Eastern Sea LOC
# the Yellow Sea LOC
# Chinese NORP
# Hong Kong GPE
# the middle of July DATE
# the middle of September DATE
# the Pacific Ocean LOC
# nine miles an hour QUANTITY
# Philippines GPE
# Chinese NORP
# Hong Kong GPE
# Chinese NORP
# November 2 DATE
# the Blue River LOC
# Yang PERSON
# Europeans NORP
# Shanghai GPE
# Yang PERSON
# Delhi GPE
# Chinese NORP
# two CARDINAL
# Shanghai GPE
# China GPE
# Europe LOC
# Shanghai GPE
# 12,000 CARDINAL
# Europeans NORP
# Chinese NORP
# 650,000 CARDINAL
# Next day DATE
# November 3 DATE
# two CARDINAL
# the Dowager Empress of China ORG
# Japan GPE
# East LOC
# Shanghai GPE
# China GPE
# European NORP
# a few minutes TIME
# Chinese NORP
# Asia LOC
# Chinese NORP
# China GPE
# Confucius PERSON
# Buddha and Socrates ORG
# three hundred CARDINAL
# Twelve CARDINAL
# three thousand CARDINAL
# Confucius PERSON
# Chinese NORP
# all ages DATE
# China GPE
# China GPE
# Chinese NORP
# Taoist NORP
# the morning TIME
# Buddhist NORP
# Confucius ORG
# three CARDINAL
# Chinese NORP
# Confucians ORG
# Taoists NORP
# Chinamen PERSON
# the seventeenth century DATE
# Manchu ORG
# Kang Hi PERSON
# China GPE
# sixty-one years DATE
# one CARDINAL
# Kien Lung PERSON
# China GPE
# nearly sixty-one years DATE
# the years DATE
# One CARDINAL
# China GPE
# Mongol NORP
# Kublai Khan PERSON
# the end of the thirteenth century DATE
# China GPE
# Chinese NORP
# Mukden PERSON
# Kang Hi PERSON
# Kien Lung PERSON
# Mukden PERSON
# Manchu ORG
# Chinese NORP
# Cantonese NORP
# Russians NORP
# Manchuria GPE
# the Japanese Korea GPE
# Canton GPE
# Chinese NORP
# one CARDINAL
# first ORDINAL
# Chinese NORP
# China GPE
# Middle Kingdom LOC
# China GPE
# the "Son of Heaven WORK_OF_ART
# five CARDINAL
# the imperial house ORG
# A few years ago DATE
# European NORP
# Peking GPE
# China GPE
# Nineveh PERSON
# 4000 years DATE
# Nineveh PERSON
# Babylon ORG
# China GPE
# Western Asia LOC
# China GPE
# three CARDINAL
# China GPE
# Two and a half centuries DATE
# the Great Wall FAC
# Plate XVII ORG
# 1500 miles QUANTITY
# 50 feet QUANTITY
# 26 CARDINAL
# 16 CARDINAL
# Chinese NORP
# China GPE
# 1553 DATE
# the third century DATE
# Eastern Turkestan LOC
# Mongolia GPE
# Chinese NORP
# Europe LOC
# China GPE
# the fourth century DATE
# Alans NORP
# overran GPE
# Europe LOC
# The Great Wall FAC
# China GPE
# the year 1280 DATE
# Khan PERSON
# Kublai Khan PERSON
# Marco Polo's PERSON
# the Grand Canal EVENT
# 174 CARDINAL
# Peking GPE
# Shanghai GPE
# Japanese NORP
# 840 miles QUANTITY
# Blue ORG
# the hundred years' DATE
# Mongols ORG
# 1644 DATE
# China GPE
# Portuguese NORP
# Macao GPE
# Hong Kong GPE
# recent decades DATE
# Europeans NORP
# Chinese NORP
# French NORP
# India GPE
# Chinese NORP
# The Great Powers ORG
# China GPE
# two CARDINAL
# Boxer PERSON
# 1900 DATE
# Peking GPE
# European NORP
# China GPE
# the "Son of Heaven WORK_OF_ART
# four CARDINAL
# Eastern Turkestan LOC
# Mongolia GPE
# Manchuria GPE
# Tibet GPE
# Chinese NORP
# thirty-five CARDINAL
# the British Isles LOC
# ten CARDINAL
# about 433 millions CARDINAL
# third ORDINAL
# fourth ORDINAL
# between winter and summer DATE
# Peking GPE
# the winter DATE
# Tea ORG
# millet PERSON
# Tibetan NORP
# China GPE
# Six CARDINAL
# eighteen CARDINAL
# harbours TIME
# one CARDINAL
# China GPE
# China GPE
# America GPE
# Greece GPE
# Europe LOC
# China GPE
# Chinese NORP
# Two thousand years DATE
# Chinese NORP
# this day DATE
# Indian NORP
# Europe LOC
# A hundred years DATE
# Christ ORG
# China GPE
# Lop-nor ORG
# Chinese NORP
# D. NORP
# 265 CARDINAL
# D. NORP
# 600 CARDINAL
# Chinese NORP
# Europe LOC
# 850 years later DATE
# Chinese NORP
# 1100 years DATE
# Europeans NORP
# Three thousand years ago DATE
# Chinese NORP

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |PERSON|People, including fictional.|
# |NORP|Nationalities or religious or political groups.|
# |FAC|Buildings, airports, highways, bridges, etc.|
# |ORG|Companies, agencies, institutions, etc.|
# |GPE|Countries, cities, states.|
# |LOC|Non-GPE locations, mountain ranges, bodies of water.|
# |PRODUCT|Objects, vehicles, foods, etc. (Not services.)|
# |EVENT|Named hurricanes, battles, wars, sports events, etc.|
# |WORK_OF_ART|Titles of books, songs, etc.|
# |LAW|Named documents made into laws.|
# |LANGUAGE|Any named language.|
# |DATE|Absolute or relative dates or periods.|
# |TIME|Times smaller than a day.|
# |PERCENT|Percentage, including ”%“.|
# |MONEY|Monetary values, including unit.|
# |QUANTITY|Measurements, as of weight or distance.|
# |ORDINAL|“first”, “second”, etc.|
# |CARDINAL|Numerals that do not fall under another type.|

# %% [markdown]
# We can display the Named Entities using spaCy displacy module.

# %%
options = {"compact": True}


#displacy.render(doc, style='dep', options = {"compact": True})
displacy.render(list(doc.sents)[0:10], style='ent', options=options)
# Out:
# /opt/homebrew/anaconda3/envs/spacy/lib/python3.10/site-packages/spacy/displacy/__init__.py:206: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Our journey begins at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stockholm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the capital of my native country.</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Leaving Stockholm by train in the evening, we travel
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     all night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  in comfortable sleeping-cars and arrive
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  at the southernmost point of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sweden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the port of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trelleborg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , where the sunlit waves sweep in from
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Baltic Sea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Here we might expect to have done with railway travelling, and we rather look for the guard to come and open the carriage doors and ask the passengers to alight.</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Surely it is not intended that the train shall go on right across the sea? </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Yet that is actually what happens.</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The same train and the same carriages, which bore us out of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stockholm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yesterday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , go calmly across
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Baltic Sea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , and we need not get out before we arrive at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The section of the train which is to go on to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is run by an engine on to a great ferry-boat moored to the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  by heavy clamps and hooks of iron.</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The rails on
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Swedish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  ground are closely connected with those on the ferry-boat, and when the carriages are pushed on board by the engine, they are fastened with chains and hooks so that they may remain quite steady even if the vessel begins to roll.</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">As the traveller lies dozing in his compartment, he will certainly hear whistles and the rattle of iron gear and will notice that the compartment suddenly becomes quite dark.</br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">But only when the monotonous groaning and the constant vibration of the wheels has given place to a gentle and silent heaving will he know that he is out on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Baltic Sea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</br></div></span>

# %% [markdown]
# I proceed to filter the GPE entities only.

# %%
places = []
for ent in doc.ents:
    if ent.label_ == "GPE":
        places.append(f'{ent}')
       

print(places[0:20])
# Out:
# ['Stockholm', 'Sweden', 'Stockholm', 'Berlin', 'Germany', 'quay', 'Germany', 'Sweden', 'Pomerania', 'Sweden', 'northern Germany', 'Berlin', 'North Germany', 'Berlin', 'Berlin', 'Germany', 'Russia', 'Berlin', 'London', 'Paris']

# %% [markdown]
# I could try and turn the list of places into a pandas dataframe.

# %%
df = pd.DataFrame()

df['place'] = places

# %% [markdown]
# and remove duplicates.

# %%
df = df.drop_duplicates()
df
# Out:
#                   place
# 0             Stockholm
# 1                Sweden
# 3                Berlin
# 4               Germany
# 5                  quay
# ..                  ...
# 757             Formosa
# 778           Manchuria
# 779  the Japanese Korea
# 791             overran
# 796               Macao
#
# [236 rows x 1 columns]

# %% [markdown]
# As we can see there are some word that were misinterpreted as places like quay. I could fix this by removing all words in lowercase as names of places are capitalized.

# %%
#This is the short way to do it with a list:

places = list(set([ent.text for ent in doc.ents if ent.label_ == "GPE" and ent.text[0].isupper()]))

# %%
#But I prefer loops because they are easier to read. 
places = []
for ent in doc.ents:
    if ent.label_ == "GPE" and ent.text[0].isupper():
        if ent.text not in places:
            places.append(ent.text)

# %%
print(places)
# Out:
# ['Stockholm', 'Sweden', 'Berlin', 'Germany', 'Pomerania', 'North Germany', 'Russia', 'London', 'Paris', 'St.\nPetersburg', 'Rome', 'Hamburg', 'Vienna', 'France', 'Prussia', 'China', 'Japan', 'Tibet', 'Bavaria', 'Saxony', 'Lübeck', 'Munich', 'Dresden', 'Leipzig', 'Cologne', 'England', 'Scotland', 'Austria', 'Brandenburg', 'Bohemia', 'Prague', "St.\nStephen's Church", 'Chechs', 'Magyars', 'Hungary', 'Polacks', 'Galicia', 'Baden', 'Rumania', 'Bulgaria', 'Budapest', 'South Germany', 'Alps', 'Magyar', 'Belgrade', 'Servia', 'Sofia', 'States', 'Albania', 'Macedonia', 'Greece', 'Turkey', 'Constantinople', 'Stambul', 'St.\nSophia', 'Asia Minor', 'Caucasia', 'Hellespont', 'Dardanelles', 'Asiatic', 'Jerusalem', 'Mecca', 'Persia', 'Turkestan', 'Arabia', 'India', 'Nishapur', 'Badakshan', 'Bahrein', 'North Africa', 'Afghanistan', 'Cairo', 'Tatars', 'Crimea', 'Samarkand', 'Bokhara', 'Terapia', 'Wales', 'Scania', 'Batum', 'Trebizond', 'Tabriz', 'Teheran', 'Turkish Armenia', 'Erzerum', 'BAGHDAD', 'Mesopotamia', 'Tigris', 'Azerbeijan', 'Moscow', 'Tiflis', 'Baku', 'Karzan', 'Kashan', 'Kuhrud', 'Ispahan', 'Persepolis', 'Bushire', 'Medina', 'Hajji', 'Adjoining Arabia', 'Baghdad', 'Kermanshah', 'Bakuba', 'Hamadan', 'Tebbes', 'Bengal', 'Seistan', 'Bukhara', 'Orenburg', 'Tashkent', 'Kirghiz', 'Ferghana', 'Italy', 'Benares', 'Lhasa', 'Tsar', 'South Russia', 'Jaipur', 'Pyrenees', 'Nasretabad', 'Hong Kong', 'Bombay', 'Baluchistan', 'Bam', 'Bam.', 'Quetta', 'Rawalpindi', 'Pattala', 'Thrace', 'Illyria', 'Damascus', 'Tyre', 'Sidon', 'Palestine', 'Egypt', 'Shushan', 'Ethiopia', 'Bactria', 'Nereids', 'Achilles', 'Srinagar', 'Kashmiris', 'Ladak', 'Yarkand', 'Mongolia', 'Merket', 'Kasim', 'Autumn', 'TIBET \nSouth', 'Burma', 'Bhutan', 'Sikkim', 'Nepal', 'Tibetan', 'Kinchinjunga', 'Australia', 'Spain', 'Portugal', 'Sicily', 'Shigatse', 'Nirvana', 'Huc', 'Gabet', 'Ördek', 'Province', 'Israel', 'Aldat', 'TIBET', 'Lebanon', 'Viceroy', 'Delhi', 'INDIA', 'Taj Mahal', 'Kapilavastu', 'Siddharta', 'Yasodara', 'Thou', 'Korea', 'Mexico', 'Nymphæa stellaris', 'Ceylon', 'Brazil', 'Sanscrit', 'Further India', 'Shanghai', 'Cape Comorin', 'Moldavia', 'America', 'Philippines', 'New Guinea', 'Sunda Islands', 'Sunda', 'Holland', 'Krakatau', 'SINGAPORE', 'Penang', 'Singapore', 'Great Britain', 'Saigon', 'Mekong', 'Annam', 'Cambodia', 'Hanoi', 'Tonkin', 'Siam', 'Laos', 'Bangkok', 'Victoria', 'Aden', 'Colombo', 'New York', 'Canton', 'Peking', 'Formosa', 'Manchuria', 'Macao']

# %% [markdown]
# Since I am going to study this geographical fiction, I will plot it as a map in simple way (there are many ways to do this).

# %%
#First I get the coordinates of the places with the service NOMINATIM from OpenStreet
from geopy.geocoders import Nominatim

# create a geocoder object for the Nominatim service
geolocator = Nominatim(user_agent="myMap")

# create an empty list to store the coordinates
coordinates = []

# iterate over each place in the list
for place in places:
    # geocode the place using Nominatim
    location = geolocator.geocode(place, exactly_one=True)

    # extract the coordinates from the location object
    if location is not None:
        lat = location.latitude
        lng = location.longitude
        coordinates.append((place, lat, lng))

print(coordinates)
# Out:
# [('Stockholm', 59.3251172, 18.0710935), ('Sweden', 59.6749712, 14.5208584), ('Berlin', 52.5170365, 13.3888599), ('Germany', 51.1638175, 10.4478313), ('Pomerania', 54.24556, 18.1099), ('North Germany', 52.404886950000005, 9.712372836460514), ('Russia', 64.6863136, 97.7453061), ('London', 51.5073359, -0.12765), ('Paris', 48.8588897, 2.3200410217200766), ('St.\nPetersburg', 27.7703796, -82.6695085), ('Rome', 41.8933203, 12.4829321), ('Hamburg', 53.550341, 10.000654), ('Vienna', 48.2083537, 16.3725042), ('France', 46.603354, 1.8883335), ('Prussia', 41.3738765, -94.506357), ('China', 35.000074, 104.999927), ('Japan', 36.5748441, 139.2394179), ('Tibet', 29.8556443, 90.8749807), ('Bavaria', 48.9467562, 11.4038717), ('Saxony', 50.9295798, 13.4585052), ('Lübeck', 53.866444, 10.684738), ('Munich', 48.1371079, 11.5753822), ('Dresden', 51.0493286, 13.7381437), ('Leipzig', 51.3406321, 12.3747329), ('Cologne', 50.938361, 6.959974), ('England', 52.5310214, -1.2649062), ('Scotland', 56.7861112, -4.1140518), ('Austria', 47.59397, 14.12456), ('Brandenburg', 52.8455492, 13.2461296), ('Bohemia', 40.7694091, -73.1148664), ('Prague', 50.0874654, 14.4212535), ("St.\nStephen's Church", 51.74183155, -0.3483744059293644), ('Hungary', 47.1817585, 19.5060937), ('Polacks', -36.5722153, 149.5926719), ('Galicia', 42.61946, -7.863112), ('Baden', 48.1928371, 8.1390286), ('Rumania', 45.9852129, 24.6859225), ('Bulgaria', 42.6073975, 25.4856617), ('Budapest', 47.48138955, 19.14609412691246), ('South Germany', 51.0859543, 6.982486), ('Alps', 45.9081401, 9.141582381412086), ('Magyar', 46.9247261, 17.629836), ('Belgrade', 44.8178131, 20.4568974), ('Servia', 44.1534121, 20.55144), ('Sofia', -15.2538402, 48.2562163), ('Albania', 41.000028, 19.9999619), ('Macedonia', 41.6171214, 21.7168387), ('Greece', 38.9953683, 21.9877132), ('Turkey', 38.9597594, 34.9249653), ('Constantinople', 41.0091982, 28.9662187), ('Stambul', 41.0091982, 28.9662187), ('St.\nSophia', 53.3999588, 14.126109106675198), ('Asia Minor', 39.05742105, 32.31123751255631), ('Caucasia', 7.8276894, -75.04524822749215), ('Hellespont', 52.4442676, 13.4087613), ('Dardanelles', 40.20917255, 26.44139082761628), ('Asiatic', 14.4231499, 120.9270891), ('Jerusalem', 31.79592425, 35.21198075969497), ('Mecca', 21.420847, 39.826869), ('Persia', 32.6475314, 54.5643516), ('Turkestan', 43.3019457, 68.2703698), ('Arabia', 22.3743008, 49.477117651597084), ('India', 22.3511148, 78.6677428), ('Nishapur', 36.210595, 58.7922805), ('Bahrein', 26.1551249, 50.5344606), ('North Africa', 13.45911, -2.2496367403016495), ('Afghanistan', 33.7680065, 66.2385139), ('Cairo', 30.0443879, 31.2357257), ('Tatars', 50.46631285, 30.48597691940264), ('Crimea', 45.28350435, 34.20081877526554), ('Samarkand', 39.6634028, 66.94416098427573), ('Bokhara', 39.7675529, 64.4231326), ('Terapia', 46.79555805, 23.616588642797826), ('Wales', 52.2928116, -3.73893), ('Scania', 46.6687106, 5.410227976911495), ('Batum', 41.6509502, 41.6360085), ('Tabriz', 38.0739964, 46.2961952), ('Teheran', 35.6892523, 51.3896004), ('Erzerum', 50.8571955, 57.8575708), ('BAGHDAD', 33.3061701, 44.3872213), ('Mesopotamia', 34.9019732, 42.059646594808214), ('Tigris', 33.324571399999996, 44.40461807035434), ('Moscow', 55.7504461, 37.6174943), ('Tiflis', 41.6934591, 44.8014495), ('Baku', 40.3755885, 49.8328009), ('Karzan', 41.829372, 69.713317), ('Kashan', 33.9876533, 51.4428856), ('Kuhrud', 39.4225922, 68.5585493), ('Ispahan', 32.6707877, 51.6650002), ('Persepolis', 29.93516685, 52.89040414267539), ('Bushire', 32.897107, -96.833492), ('Medina', 29.2836281, -99.1126826), ('Hajji', 34.0002346, -6.7456214), ('Baghdad', 33.3061701, 44.3872213), ('Kermanshah', 34.3789744, 46.7010122), ('Bakuba', 33.7437267, 44.6495225), ('Hamadan', 34.973321, 48.6555779), ('Bengal', 39.4735045, -85.9228997), ('Seistan', 32.6337033, -115.1935574), ('Bukhara', 39.7675529, 64.4231326), ('Orenburg', 51.7671248, 55.0978517), ('Tashkent', 41.3123363, 69.2787079), ('Kirghiz', 39.7141576, 76.1645911), ('Ferghan ...

# %% [markdown]
# Now that I have the coordinate, I plot the map.

# %%
import folium

# create a map centered on the first coordinate in the list
map_center = coordinates[0][1], coordinates[0][2]
m = folium.Map(location=map_center, zoom_start=10)

# add a marker for each coordinate in the list
for place, lat, lng in coordinates:
    tooltip = place
    marker = folium.Marker([lat, lng], tooltip=tooltip)
    marker.add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68b00cab66c02ec626f508af11ec9303 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68b00cab66c02ec626f508af11ec9303&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68b00cab66c02ec626f508af11ec9303 = L.map(
#                 &quot;map_68b00cab66c02ec626f508af11ec9303&quot;,
#                 {
#                     center: [59.3251172, 18.0710935],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f47f1be14f62fd35571e32cc85fc508 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             var marker_99d60397fe735e367256bb07e44070b1 = L.marker(
#                 [59.3251172, 18.0710935],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_99d60397fe735e367256bb07e44070b1.bindTooltip(
#                 `&lt;div&gt;
#                      Stockholm
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8ca4226f451d7870892f4b66c3414fa = L.marker(
#                 [59.6749712, 14.5208584],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_b8ca4226f451d7870892f4b66c3414fa.bindTooltip(
#                 `&lt;div&gt;
#                      Sweden
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c0db46e8324fb2f329336c705627bd50 = L.marker(
#                 [52.5170365, 13.3888599],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_c0db46e8324fb2f329336c705627bd50.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_325ffe1afbc146eb3d22a97acd8d3c9a = L.marker(
#                 [51.1638175, 10.4478313],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_325ffe1afbc146eb3d22a97acd8d3c9a.bindTooltip(
#                 `&lt;div&gt;
#                      Germany
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_228c71d42937f3d173c670703cea688e = L.marker(
#                 [54.24556, 18.1099],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_228c71d42937f3d173c670703cea688e.bindTooltip(
#                 `&lt;div&gt;
#                      Pomerania
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aad67a3dec95c30d596fc6092451a3cb = L.marker(
#                 [52.404886950000005, 9.712372836460514],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_aad67a3dec95c30d596fc6092451a3cb.bindTooltip(
#                 `&lt;div&gt;
#                      North Germany
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0b58754688d42bcc693a7fa61f1b137 = L.marker(
#                 [64.6863136, 97.7453061],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_b0b58754688d42bcc693a7fa61f1b137.bindTooltip(
#                 `&lt;div&gt;
#                      Russia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d3df42b246fba8d93d4beb57f80e4c6 = L.marker(
#                 [51.5073359, -0.12765],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_9d3df42b246fba8d93d4beb57f80e4c6.bindTooltip(
#                 `&lt;div&gt;
#                      London
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2ef08abf3f80b1352c6530fc771da62b = L.marker(
#                 [48.8588897, 2.3200410217200766],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);
#
#
#             marker_2ef08abf3f80b1352c6530fc771da62b.bindTooltip(
#                 `&lt;div&gt;
#                      Paris
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c95e8801424a35ded82562c5667b0fb4 = L.marker(
#                 [27.7703796, -82.6695085],
#                 {}
#             ).addTo(map_68b00cab66c02ec626f508af11ec9303);

# %% [markdown]
# But I want more than the map. It would be nice I could track the movement in space of people and objects.  For this I will use other annotations provided by the spaCy doc. Let's take a look at the syntax of one sentence from the book which describes movement in space:

# %%
text = 'The traveller goes from Paris to St. Petersburg'

doc = nlp(text)

options = {"compact": True, "bg": "#9FA6B2",
           "color": "black"}


displacy.render(doc, style='dep', options = {"compact": True})
#displacy.render(list(doc.sents)[0], style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="85dc058f67154f5cb144592c234e6e8a-0" class="displacy" width="1250" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">traveller</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">goes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Paris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">St.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Petersburg</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-0" stroke-width="2px" d="M62,152.0 62,127.0 197.0,127.0 197.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-1" stroke-width="2px" d="M212,152.0 212,127.0 347.0,127.0 347.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,154.0 L208,146.0 216,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-2" stroke-width="2px" d="M362,152.0 362,127.0 497.0,127.0 497.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M497.0,154.0 L501.0,146.0 493.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-3" stroke-width="2px" d="M512,152.0 512,127.0 647.0,127.0 647.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M647.0,154.0 L651.0,146.0 643.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-4" stroke-width="2px" d="M362,152.0 362,102.0 800.0,102.0 800.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M800.0,154.0 L804.0,146.0 796.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-5" stroke-width="2px" d="M962,152.0 962,127.0 1097.0,127.0 1097.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,154.0 L958,146.0 966,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-85dc058f67154f5cb144592c234e6e8a-0-6" stroke-width="2px" d="M812,152.0 812,102.0 1100.0,102.0 1100.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-85dc058f67154f5cb144592c234e6e8a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,154.0 L1104.0,146.0 1096.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
#We can use spacy.explain() function to know what the technical termns mean

spacy.explain("nsubj")
#spacy.explain("pobj")
#spacy.explain("PROPN")
# Out:
# 'proper noun'

# %% [markdown]
# | POS | Description |
# | --- | ----------- |
# | ADJ | adjective |
# | ADP| adposition |
# | ADV | adverb |
# | AUX | auxiliary |
# | CCONJ|  coordinating conjunction |
# | DET | determiner |
# | INTJ | interjection |
# | NOUN | noun |
# | NUM | numeral |
# | PART | particle |
# | PRON | pronoun |
# | PROPN | proper noun |
# | PUNCT | punctuation |
# | SCONJ | subordinating conjunction |
# | SYM | symbol |
# | VERB | verb |
# | X | other |

# %% [markdown]
# The terminology comes from the Universal Dependencies project. UD treebanks are used to train language models. Take a look at a sample of the training data:
#
# ```
# # sent_id = GUM_academic_art-8
# # s_prominence = 2
# # s_type = wh
# # transition = establishment
# # text = Which elements of specific artworks do they focus on?
# 1	Which	which	DET	WDT	PronType=Int	2	det	2:det	Discourse=joint-list_m:8->7:0|Entity=(21-abstract-new-cf2-2-sgl
# 2	elements	element	NOUN	NNS	Number=Plur	8	obl	8:obl:on	_
# 3	of	of	ADP	IN	_	5	case	5:case	_
# 4	specific	specific	ADJ	JJ	Degree=Pos	5	amod	5:amod	Entity=(22-object-new-cf3-2-sgl
# 5	artworks	artwork	NOUN	NNS	Number=Plur	2	nmod	2:nmod:of	Entity=22)21)
# 6	do	do	AUX	VBP	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	8	aux	8:aux	_
# 7	they	they	PRON	PRP	Case=Nom|Number=Plur|Person=3|PronType=Prs	8	nsubj	8:nsubj	Entity=(19-person-giv:act-cf1*-1-ana)
# 8	focus	focus	VERB	VB	VerbForm=Inf	0	root	0:root	_
# 9	on	on	ADP	IN	_	2	case	2:case	SpaceAfter=No
# 10	?	?	PUNCT	.	_	8	punct	8:punct	_
# ```

# %% [markdown]
# Now that we have an idea of the syntax of the sentence, we can proceed to extract some travel information using a syntantic machter:

# %%
import spacy
from spacy.matcher import DependencyMatcher
from spacy.tokens import Span



# Define the pattern for matching the "go to" construction
pattern = [
    {
        "RIGHT_ID": "verb",
        "RIGHT_ATTRS": {"LEMMA": "go"},
        #"RIGHT_ATTRS": {"POS": "VERB"},
    },
    {
        "LEFT_ID": "verb",
        "REL_OP": ">",
        "RIGHT_ID": "subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {   "LEFT_ID": "verb",
        "REL_OP": ">",
        "RIGHT_ID": "preposition",
        "RIGHT_ATTRS": {"DEP": "prep"},
        "RIGHT_ATTRS": {"LEMMA": "to"},
    },
    {   "LEFT_ID": "preposition",
        "REL_OP": ">",
        "RIGHT_ID": "place",
        "RIGHT_ATTRS": {"ENT_TYPE": "GPE"},
    }
]

# Create a dependency matcher object
matcher = DependencyMatcher(nlp.vocab)
matcher.add("go_to", [pattern])

# Define a sample text
#text = "John went to Paris. Mary will go to Rome tomorrow."
text = open("FromPoleToPole.txt").read()

# Process the text with the nlp object
doc = nlp(text)

dep_matches = matcher(doc)

#match_id, token_ids = matches[1]
#for i in range(len(token_ids)):
#    print(pattern[i]["RIGHT_ID"] + ":", doc[token_ids[i]].text)

print(dep_matches)
# Out:
# [(14076869952056337076, [1698, 1697, 1701, 1704]), (14076869952056337076, [68321, 68315, 68323, 68324])]

# %%
# Loop over each tuple in the list 'dep_matches'
for match in dep_matches:
    
    # Take the first item in the tuple at [0] and assign it under
    # the variable 'pattern_name'. This item is a spaCy Lexeme object.
    pattern_name = match[0]
    
    # Take the second item in the tuple at [1] and assign it under
    # the variable 'matches'. This is a list of indices referring to the
    # Doc object under 'doc' that we just matched.
    matches = match[1]
    
    # Let's unpack the matches list into variables for clarity
    verb, subject, prep, place = matches[0], matches[1], matches[2], matches[3]
    4
    # Print the matches by first fetching the name of the pattern from the 
    # Vocabulary object. Next, use the 'subject' and 'verb' variables to 
    # index the Doc object. This gives us the actual Tokens matched. Use a
    # tabulator ('\t') and some stops ('...') to separate the output.
    print(nlp.vocab[pattern_name].text, '\t', doc[subject], doc[verb], doc[prep], doc[place])
# Out:
# go_to 	 traveller goes to Petersburg
# go_to 	 opium goes to China

# %% [markdown]
# Since we are getting to few matches we need to consider adding more verbs or making the patterns more flexible.  Let take a look at the verbs in the texts:

# %%
verbs = []
for token in doc:
    if token.pos_ == "VERB":
       verbs.append(token.lemma_)

#turn list to set to eliminate duplicates:
verbs = sorted(set(verbs))       

print(verbs)
# Out:
# ['ARABIA', 'BUKHARA', 'abandon', 'abash', 'abdicate', 'abound', 'absorb', 'abstain', 'accommodate', 'accompany', 'accord', 'accustom', 'achieve', 'acknowledge', 'acquaint', 'acquire', 'act', 'adhere', 'admire', 'adopt', 'adorn', 'advance', 'affect', 'affix', 'afford', 'agree', 'aim', 'allow', 'ally', 'alter', 'amount', 'amuse', 'anchor', 'animate', 'annex', 'announce', 'annul', 'answer', 'appear', 'apply', 'appoint', 'appreciate', 'approach', 'arise', 'arm', 'arouse', 'arrange', 'arrive', 'articulate', 'ascend', 'ascertain', 'ask', 'assassinate', 'assemble', 'assert', 'assume', 'assure', 'attach', 'attack', 'attain', 'attempt', 'attend', 'attract', 'augment', 'avail', 'avoid', 'await', 'awake', 'awaken', 'back', 'baku', 'balance', 'bar', 'barebacke', 'barefoote', 'bareheade', 'barge', 'bark', 'barter', 'bathe', 'be', 'bear', 'beat', 'beckon', 'become', 'befall', 'beg', 'begin', 'behave', 'behold', 'believe', 'belong', 'bend', 'benefit', 'benumb', 'beseech', 'beset', 'bestow', 'betake', 'betroth', 'bid', 'bind', 'bit', 'bite', 'bivouac', 'blacken', 'blast', 'blaze', 'blend', 'bless', 'blindfold', 'blister', 'blossom', 'blow', 'boast', 'bob', 'boil', 'bound', 'bow', 'branch', 'brandish', 'break', 'breathe', 'bree', 'brigand', 'bring', 'bruise', 'brush', 'bubble', 'build', 'bump', 'burn', 'burrow', 'bury', 'bustle', 'buy', 'buzz', 'calculate', 'call', 'camel', 'cap', 'capsize', 'capture', 'care', 'caress', 'carpet', 'carry', 'carve', 'cast', 'catch', 'cause', 'cease', 'celebrate', 'change', 'chase', 'chatter', 'check', 'cheer', 'cherish', 'chew', 'choke', 'choose', 'churn', 'circle', 'circulate', 'clamber', 'clang', 'clash', 'clean', 'clear', 'climb', 'cling', 'close', 'clothe', 'cloud', 'cock', 'collect', 'colour', 'come', 'command', 'commemorate', 'commence', 'commit', 'communicate', 'compare', 'compel', 'compensate', 'compile', 'complain', 'complete', 'compose', 'compress', 'conceal', 'conceive', 'condense', 'conduct', 'confide', 'confine', 'congeal', 'conjure', 'connect', 'conquer', 'consecrate', 'consent', 'consider', 'consist', 'constitute', 'construct', 'consume', 'contact', 'contain', 'contend', 'content', 'continue', 'contribute', 'contrive', 'control', 'converge', 'convert', 'convey', 'convince', 'cook', 'cool', 'correspond', 'corrupt', 'cost', 'count', 'cover', 'crack', 'crackle', 'crawl', 'creak', 'create', 'creep', 'crop', 'cross', 'crouch', 'crowd', 'crown', 'crunch', 'crush', 'cry', 'cultivate', 'cure', 'curl', 'cut', 'damage', 'dance', 'dangle', 'dare', 'dart', 'dash', 'dawn', 'daze', 'dazzle', 'deafen', 'decay', 'decide', 'deck', 'decorate', 'decoy', 'dedicate', 'defeat', 'defend', 'define', 'degrade', 'deject', 'delay', 'demand', 'depart', 'depend', 'deposit', 'deprive', 'derive', 'descend', 'describe', 'descry', 'desecrate', 'desert', 'deserve', 'desire', 'despatch', 'destroy', 'detect', 'determine', 'devastate', 'develop', 'devise', 'devote', 'devour', 'die', 'dig', 'digge', 'dignify', 'diminish', 'dip', 'direct', 'disappear', 'discharge', 'discover', 'disfigure', 'disguise', 'dishonour', 'disintegrate', 'dismount', 'dispense', 'disperse', 'display', 'disregard', 'disseminate', 'distinguish', 'distribute', 'disturb', 'dive', 'diverge', 'divert', 'divide', 'do', 'dominate', 'doom', 'double', 'doze', 'drag', 'drank', 'drape', 'draw', 'dream', 'dress', 'drift', 'drink', 'drip', 'drive', 'drop', 'drown', 'dry', 'dwell', 'dwelt', 'dye', 'eat', 'echo', 'eject', 'elapse', 'elongate', 'elude', 'embrace', 'embroider', 'emerge', 'emit', 'employ', 'empty', 'enable', 'encamp', 'enclose', 'encourage', 'encroach', 'end', 'endeavour', 'endow', 'enervate', 'engage', 'enjoy', 'enliven', 'entangle', 'enter', 'entertain', 'entice', 'entrust', 'envelop', 'erect', 'escape', 'escort', 'establish', 'evaporate', 'exact', 'examine', 'exceed', 'exchange', 'excite', 'exclaim', 'execute', 'exercise', 'exert', 'exhaust', 'exhibit', 'exist', 'expand', 'expect', 'experience', 'explode', 'explore', 'export', 'expose', 'express', 'extend', 'e ...

# %% [markdown]
# Since there are too many verbs, we filter them using a list of synonyms that I can extract from Wordnet, using nltk.

# %%
from nltk.corpus import wordnet
nltk.download('wordnet')

synonyms = []

for syn in wordnet.synsets("go"):
    for lemma in syn.lemmas():
        if lemma.name() in verbs:
            synonyms.append(lemma.name())

print(set(synonyms))
# Out:
# {'lead', 'pass', 'perish', 'move', 'choke', 'fling', 'offer', 'work', 'start', 'turn', 'belong', 'live', 'travel', 'get', 'run', 'become', 'fit', 'go', 'whirl', 'sound', 'depart', 'crack', 'die', 'extend', 'survive', 'last', 'fail', 'break', 'proceed', 'blend'}
# [nltk_data] Downloading package wordnet to /Users/jacobo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import spacy
from spacy.matcher import DependencyMatcher
from spacy.tokens import Span


# Define the pattern for matching the "go to" construction
pattern = [
    {
        "RIGHT_ID": "verb",
    #Here I add the list of verbs to the lemma the matcher should check. 
        "RIGHT_ATTRS": {"LEMMA": {"IN": synonyms,"POS": "VERB"}}, 

    },
    {
        "LEFT_ID": "verb",
        "REL_OP": ">",
        "RIGHT_ID": "subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {   "LEFT_ID": "verb",
        "REL_OP": ">",
        "RIGHT_ID": "preposition",
        "RIGHT_ATTRS": {"DEP": "prep"},
        "RIGHT_ATTRS": {"LEMMA": "to"},
    },
    {   "LEFT_ID": "preposition",
        "REL_OP": ">",
        "RIGHT_ID": "place",
        "RIGHT_ATTRS": {"ENT_TYPE": "GPE"},
    }
]

# Create a dependency matcher object
matcher = DependencyMatcher(nlp.vocab)
matcher.add("go_to", [pattern])

# Define a sample text
#text = "John went to Paris. Mary will go to Rome tomorrow."
text = open("FromPoleToPole.txt").read()

# Process the text with the nlp object
doc = nlp(text)

dep_matches = matcher(doc)

#match_id, token_ids = matches[1]
#for i in range(len(token_ids)):
#    print(pattern[i]["RIGHT_ID"] + ":", doc[token_ids[i]].text)

# Loop over each tuple in the list 'dep_matches'
for match in dep_matches:
    
    # Take the first item in the tuple at [0] and assign it under
    # the variable 'pattern_name'. This item is a spaCy Lexeme object.
    pattern_name = match[0]
    
    # Take the second item in the tuple at [1] and assign it under
    # the variable 'matches'. This is a list of indices referring to the
    # Doc object under 'doc' that we just matched.
    matches = match[1]
    
    # Let's unpack the matches list into variables for clarity
    verb, subject, prep, place = matches[0], matches[1], matches[2], matches[3]
    4
    # Print the matches by first fetching the name of the pattern from the 
    # Vocabulary object. Next, use the 'subject' and 'verb' variables to 
    # index the Doc object. This gives us the actual Tokens matched. Use a
    # tabulator ('\t') and some stops ('...') to separate the output.
    print(nlp.vocab[pattern_name].text, '\t', doc[subject], doc[verb], doc[prep], doc[place])
# Out:
# go_to 	 traveller goes to Petersburg
# go_to 	 which runs to Teheran
# go_to 	 I travelled to Teheran
# go_to 	 he offered to Nereids
# go_to 	 opium goes to China
